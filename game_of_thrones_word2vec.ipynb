# %% [markdown]
# <a href="https://colab.research.google.com/github/saincoder404/NLP_lectures/blob/main/game_of_thrones_word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.25.2)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.0.4)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim) (1.14.1)

# %%
import gensim
import os

# %%
import os
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
from gensim.utils import simple_preprocess

story = []
for filename in os.listdir('data'):
    try:
        with open(os.path.join('data', filename), encoding='utf-8', errors='ignore') as f:
            corups = f.read()

        raw_sent = sent_tokenize(corups)
        for sent in raw_sent:
            story.append(simple_preprocess(sent))
    except Exception as e:
        print(f"Error processing file {filename}: {e}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
story
# Out:
# [['version',
#   'history',
#   'reedited',
#   'by',
#   'maelstrom',
#   'feast',
#   'for',
#   'crows',
#   'book',
#   'four',
#   'song',
#   'of',
#   'ice',
#   'and',
#   'fire',
#   'george'],
#  ['martin', 'prologue', 'dragons', 'said', 'mollander'],
#  ['he',
#   'snatched',
#   'withered',
#   'apple',
#   'off',
#   'the',
#   'ground',
#   'and',
#   'tossed',
#   'it',
#   'hand',
#   'to',
#   'hand'],
#  ['throw', 'the', 'apple', 'urged', 'alleras', 'the', 'sphinx'],
#  ['he',
#   'slipped',
#   'an',
#   'arrow',
#   'from',
#   'his',
#   'quiver',
#   'and',
#   'nocked',
#   'it',
#   'to',
#   'his',
#   'bowstring'],
#  ['should', 'like', 'to', 'see', 'dragon'],
#  ['roone',
#   'was',
#   'the',
#   'youngest',
#   'of',
#   'them',
#   'chunky',
#   'boy',
#   'still',
#   'two',
#   'years',
#   'shy',
#   'of',
#   'manhood'],
#  ['should', 'like', 'that', 'very', 'much'],
#  ['and',
#   'should',
#   'like',
#   'to',
#   'sleep',
#   'with',
#   'roseys',
#   'arms',
#   'around',
#   'me',
#   'pate',
#   'thought'],
#  ['he', 'shifted', 'restlessly', 'on', 'the', 'bench'],
#  ['by', 'the', 'morrow', 'the', 'girl', 'could', 'well', 'be', 'his'],
#  ['will',
#   'take',
#   'her',
#   'far',
#   'from',
#   'oldtown',
#   'across',
#   'the',
#   'narrow',
#   'sea',
#   'to',
#   'one',
#   'of',
#   'the',
#   'free',
#   'cities'],
#  ['there',
#   'were',
#   'no',
#   'maesters',
#   'there',
#   'no',
#   'one',
#   'to',
#   'accuse',
#   'him'],
#  ['he',
#   'could',
#   'hear',
#   'emmas',
#   'laughter',
#   'coming',
#   'through',
#   'shuttered',
#   'window',
#   'overhead',
#   'mingled',
#   'with',
#   'the',
#   'deeper',
#   'voice',
#   'of',
#   'the',
#   'man',
#   'she',
#   'was',
#   'entertaining'],
#  ['she',
#   'was',
#   'the',
#   'oldest',
#   'of',
#   'the',
#   'serving',
#   'wenches',
#   'at',
#   'the',
#   'quill',
#   'and',
#   'tankard',
#   'forty',
#   'if',
#   'she',
#   'was',
#   'day',
#   'but',
#   'still',
#   'pretty',
#   'in',
#   'fleshy',
#   'sort',
#   'of',
#   'way'],
#  ['rosey', 'was', 'her', 'daughter', 'fifteen', 'and', 'freshly', 'flowered'],
#  ['emma',
#   'had',
#   'decreed',
#   'that',
#   'roseys',
#   'maidenhead',
#   'would',
#   'cost',
#   'golden',
#   'dragon'],
#  ['pate',
#   'had',
#   'saved',
#   'nine',
#   'silver',
#   'stags',
#   'and',
#   'pot',
#   'of',
#   'copper',
#   'stars',
#   'and',
#   'pennies',
#   'for',
#   'all',
#   'the',
#   'good',
#   'that',
#   'would',
#   'do',
#   'him'],
#  ['he',
#   'would',
#   'have',
#   'stood',
#   'better',
#   'chance',
#   'of',
#   'hatching',
#   'real',
#   'dragon',
#   'than',
#   'saving',
#   'up',
#   'enough',
#   'coin',
#   'to',
#   'make',
#   'golden',
#   'one'],
#  ['you',
#   'were',
#   'born',
#   'too',
#   'late',
#   'for',
#   'dragons',
#   'lad',
#   'armen',
#   'the',
#   'acolyte',
#   'told',
#   'roone'],
#  ['armen',
#   'wore',
#   'leather',
#   'thong',
#   'about',
#   'his',
#   'neck',
#   'strung',
#   'with',
#   'links',
#   'of',
#   'pewter',
#   'tin',
#   'lead',
#   'and',
#   'copper',
#   'and',
#   'like',
#   'most',
#   'acolytes',
#   'he',
#   'seemed',
#   'to',
#   'believe',
#   'that',
#   'novices',
#   'had',
#   'turnips',
#   'growing',
#   'from',
#   'their',
#   'shoulders',
#   'in',
#   'place',
#   'of',
#   'heads'],
#  ['the',
#   'last',
#   'one',
#   'perished',
#   'during',
#   'the',
#   'reign',
#   'of',
#   'king',
#   'aegon',
#   'the',
#   'third'],
#  ['the', 'last', 'dragon', 'in', 'westeros', 'insisted', 'mollander'],
#  ['throw', 'the', 'apple', 'alleras', 'urged', 'again'],
#  ['he', 'was', 'comely', 'youth', 'their', 'sphinx'],
#  ['all', 'the', 'serving', 'wenches', 'doted', 'on', 'him'],
#  ['even',
#   'rosey',
#   'would',
#   'sometimes',
#   'touch',
#   'him',
#   'on',
#   'the',
#   'arm',
#   'when',
#   'she',
#   'brought',
#   'him',
#   'wine',
#   'and',
#   'pate',
#   'had',
#   'to',
#   'gnash',
#   'his',
#   'teeth',
#   'and',
#   'pretend',
#   'not',
#   'to',
#   'see'],
#  ['the',
#   'last',
#   'dragon',
#   'in',
#   'westeros',
#   'was',
#   'the',
#   'last',
#   'dragon',
#   'said',
#   'armen',
#   'doggedly'],
#  ['that', 'is', 'well', 'known'],
#  ['the', 'apple', 'alleras', 'said'],
#  ['unless', 'you', 'mean', 'to', 'eat', 'it'],
#  ['here'],
#  ['dragging',
#   'his',
#   'clubfoot',
#   'mollander',
#   'took',
#   'short',
#   'hop',
#   'whirled',
#   'and',
#   'whipped',
#   'the',
#   'apple',
#   'sidearm',
#   'into',
#   'the',
#   'mists',
#   'that',
#   'hung',
#   'above',
#   'the',
#   'honeywine'],
#  ['if',
#   'not',
#   'for',
#   'his',
#   'foot',
#   'he',
#   'would',
#   'have',
#   'been',
#   'knight',
#   'like',
#   'his',
#   'father'],
#  ['he',
#   'had',
#   'the',
#   'strength',
#   'for',
#   'it',
#   'in',
#   'those',
#   'thick',
#   'arms',
#   'and',
#   'broad',
#   'shoulders'],
#  ['far',
#   'and',
#   'fast',
#   'the',
#   'apple',
#   'flew',
#   'but',
#   'not',
#   'as',
#   'fast',
#   'as',
#   'the',
#   'arrow',
#   'that',
#   'whistled',
#   'after',
#   'it',
#   'yard',
#   'long',
#   'shaft',
#   'of',
#   'golden',
#   'wood',
#   'fletched',
#   'with',
#   'scarlet',
#   'feathers'],
#  ['pate',
#   'did',
#   'not',
#   'see',
#   'the',
#   'arrow',
#   'catch',
#   'the',
#   'apple',
#   'but',
#   'he',
#   'heard',
#   'it'],
#  ['soft',
#   'chunk',
#   'echoed',
#   'back',
#   'across',
#   'the',
#   'river',
#   'followed',
#   'by',
#   'splash'],
#  ['mollander', 'whistled'],
#  ['you', 'cored', 'it'],
#  ['sweet'],
#  ['not', 'half', 'as', 'sweet', 'as', 'rosey'],
#  ['pate',
#   'loved',
#   'her',
#   'hazel',
#   'eyes',
#   'and',
#   'budding',
#   'breasts',
#   'and',
#   'the',
#   'way',
#   'she',
#   'smiled',
#   'every',
#   'time',
#   'she',
#   'saw',
#   'him'],
#  ['he', 'loved', 'the', 'dimples', 'in', 'her', 'cheeks'],
#  ['sometimes',
#   'she',
#   'went',
#   'barefoot',
#   'as',
#   'she',
#   'served',
#   'to',
#   'feel',
#   'the',
#   'grass',
#   'beneath',
#   'her',
#   'feet'],
#  ['he', 'loved', 'that', 'too'],
#  ['he',
#   'loved',
#   'the',
#   'clean',
#   'fresh',
#   'smell',
#   'of',
#   'her',
#   'the',
#   'way',
#   'her',
#   'hair',
#   'curled',
#   'behind',
#   'her',
#   'ears'],
#  ['he', 'even', 'loved', 'her', 'toes'],
#  ['one',
#   'night',
#   'shed',
#   'let',
#   'him',
#   'rub',
#   'her',
#   'feet',
#   'and',
#   'play',
#   'with',
#   'them',
#   'and',
#   'hed',
#   'made',
#   'up',
#   'funny',
#   'tale',
#   'for',
#   'every',
#   'toe',
#   'to',
#   'keep',
#   'her',
#   'giggling'],
#  ['perhaps',
#   'he',
#   'would',
#   'do',
#   'better',
#   'to',
#   'remain',
#   'on',
#   'this',
#   'side',
#   'of',
#   'the',
#   'narrow',
#   'sea'],
#  ['he',
#   'could',
#   'buy',
#   'donkey',
#   'with',
#   'the',
#   'coin',
#   'hed',
#   'saved',
#   'and',
#   'he',
#   'and',
#   'rosey',
#   'could',
#   'take',
#   'turns',
#   'riding',
#   'it',
#   'as',
#   'they',
#   'wandered',
#   'westeros'],
#  ['ebrose',
#   'might',
#   'not',
#   'think',
#   'him',
#   'worthy',
#   'of',
#   'the',
#   'silver',
#   'but',
#   'pate',
#   'knew',
#   'how',
#   'to',
#   'set',
#   'bone',
#   'and',
#   'leech',
#   'fever'],
#  ['the', 'smallfolk', 'would', 'be', 'grateful', 'for', 'his', 'help'],
#  ['if',
#   'he',
#   'could',
#   'learn',
#   'to',
#   'cut',
#   'hair',
#   'and',
#   'shave',
#   'beards',
#   'he',
#   'might',
#   'even',
#   'be',
#   'barber'],
#  ['that',
#   'would',
#   'be',
#   'enough',
#   'he',
#   'told',
#   'himself',
#   'so',
#   'long',
#   'as',
#   'had',
#   'rosey'],
#  ['rosey', 'was', 'all', 'that', 'he', 'wanted', 'in', 'the', 'world'],
#  ['that', 'had', 'not', 'always', 'been', 'so'],
#  ['once',
#   'he',
#   'had',
#   'dreamed',
#   'of',
#   'being',
#   'maester',
#   'in',
#   'castle',
#   'in',
#   'service',
#   'to',
#   'some',
#   'open',
#   'handed',
#   'lord',
#   'who',
#   'would',
#   'honor',
#   'him',
#   'for',
#   'his',
#   'wisdom',
#   'and',
#   'bestow',
#   'fine',
#   'white',
#   'horse',
#   'on',
#   'him',
#   'to',
#   'thank',
#   'him',
#   'for',
#   'his',
#   'service'],
#  ['how',
#   'high',
#   'hed',
#   'ride',
#   'how',
#   'nobly',
#   'smiling',
#   'down',
#   'at',
#   'the',
#   'smallfolk',
#   'when',
#   'he',
#   'passed',
#   'them',
#   'on',
#   'the',
#   'road',
#   'one',
#   'night',
#   'in',
#   'the',
#   'quill',
#   'and',
#   'tankards',
#   'common',
#   'room',
#   'after',
#   'his',
#   'second',
#   'tankard',
#   'of',
#   'fearsomely',
#   'strong',
#   'cider',
#   'pate',
#   'had',
#   'boasted',
#   'that',
#   'he',
#   'would',
#   'not',
#   'always',
#   'be',
#   'novice'],
#  ['too', 'true', 'lazy', 'leo', 'had', 'called', 'out'],
#  ['youll', 'be', 'former', 'novice', 'herding', 'swine'],
#  ['he', 'drained', 'the', 'dregs', 'of', 'his', 'tankard'],
#  ['the',
#   'torchlit',
#   'terrace',
#   'of',
#   'the',
#   'quill',
#   'and',
#   'tankard',
#   'was',
#   'an',
#   'island',
#   'of',
#   'light',
#   'in',
#   'sea',
#   'of',
#   'mist',
#   'this',
#   'morning'],
#  ['downriver',
#   'the',
#   'distant',
#   'beacon',
#   'of',
#   'the',
#   'hightower',
#   'floated',
#   'in',
#   'the',
#   'damp',
#   'of',
#   'night',
#   'like',
#   'hazy',
#   'orange',
#   'moon',
#   'but',
#   'the',
#   'light',
#   'did',
#   'little',
#   'to',
#   'lift',
#   'his',
#   'spirits'],
#  ['the', 'alchemist', 'should', 'have', 'come', 'by', 'now'],
#  ['had',
#   'it',
#   'all',
#   'been',
#   'some',
#   'cruel',
#   'jape',
#   'or',
#   'had',
#   'something',
#   'happened',
#   'to',
#   'the',
#   'man'],
#  ['it',
#   'would',
#   'not',
#   'have',
#   'been',
#   'the',
#   'first',
#   'time',
#   'that',
#   'good',
#   'fortune',
#   'had',
#   'turned',
#   'sour',
#   'on',
#   'pate'],
#  ['he',
#   'had',
#   'once',
#   'counted',
#   'himself',
#   'lucky',
#   'to',
#   'be',
#   'chosen',
#   'to',
#   'help',
#   'old',
#   'archmaester',
#   'walgrave',
#   'with',
#   'the',
#   'ravens',
#   'never',
#   'dreaming',
#   'that',
#   'before',
#   'long',
#   'he',
#   'would',
#   'also',
#   'be',
#   'fetching',
#   'the',
#   'mans',
#   'meals',
#   'sweeping',
#   'out',
#   'his',
#   'chambers',
#   'and',
#   'dressing',
#   'him',
#   'every',
#   'morning'],
#  ['everyone',
#   'said',
#   'that',
#   'walgrave',
#   'had',
#   'forgotten',
#   'more',
#   'of',
#   'ravencraft',
#   'than',
#   'most',
#   'maesters',
#   'ever',
#   'knew',
#   'so',
#   'pate',
#   'assumed',
#   'black',
#   'iron',
#   'link',
#   'was',
#   'the',
#   'least',
#   'that',
#   'he',
#   'could',
#   'hope',
#   'for',
#   'only',
#   'to',
#   'find',
#   'that',
#   'walgrave',
#   'could',
#   'not',
#   'grant',
#   'him',
#   'one'],
#  ['the',
#   'old',
#   'man',
#   'remained',
#   'an',
#   'archmaester',
#   'only',
#   'by',
#   'courtesy'],
#  ['as',
#   'great',
#   'maester',
#   'as',
#   'once',
#   'hed',
#   'been',
#   'now',
#   'his',
#   'robes',
#   'concealed',
#   'soiled',
#   'smallclothes',
#   'oft',
#   'as',
#   'not',
#   'and',
#   'half',
#   'year',
#   'ago',
#   'some',
#   'acolytes',
#   'found',
#   'him',
#   'weeping',
#   'in',
#   'the',
#   'library',
#   'unable',
#   'to',
#   'find',
#   'his',
#   'way',
#   'back',
#   'to',
#   'his',
#   'chambers'],
#  ['maester',
#   'gormon',
#   'sat',
#   'below',
#   'the',
#   'iron',
#   'mask',
#   'in',
#   'walgraves',
#   'place',
#   'the',
#   'same',
#   'gormon',
#   'who',
#   'had',
#   'once',
#   'accused',
#   'pate',
#   'of',
#   'theft'],
#  ['in',
#   'the',
#   'apple',
#   'tree',
#   'beside',
#   'the',
#   'water',
#   'nightingale',
#   'began',
#   'to',
#   'sing'],
#  ['it',
#   'was',
#   'sweet',
#   'sound',
#   'welcome',
#   'respite',
#   'from',
#   'the',
#   'harsh',
#   'screams',
#   'and',
#   'endless',
#   'quorking',
#   'of',
#   'the',
#   'ravens',
#   'he',
#   'had',
#   'tended',
#   'all',
#   'day',
#   'long'],
#  ['the',
#   'white',
#   'ravens',
#   'knew',
#   'his',
#   'name',
#   'and',
#   'would',
#   'mutter',
#   'it',
#   'to',
#   'each',
#   'other',
#   'whenever',
#   'they',
#   'caught',
#   'sight',
#   'of',
#   'him',
#   'pate',
#   'pate',
#   'pate',
#   'until',
#   'he',
#   'wanted',
#   'to',
#   'scream'],
#  ['the', 'big', 'white', 'birds', 'were', 'archmaester', 'walgraves', 'pride'],
#  ['he',
#   'wanted',
#   'them',
#   'to',
#   'eat',
#   'him',
#   'when',
#   'he',
#   'died',
#   'but',
#   'pate',
#   'half',
#   'suspected',
#   'that',
#   'they',
#   'meant',
#   'to',
#   'eat',
#   'him',
#   'too'],
#  ['perhaps',
#   'it',
#   'was',
#   'the',
#   'fearsomely',
#   'strong',
#   'ciderhe',
#   'had',
#   'not',
#   'come',
#   'here',
#   'to',
#   'drink',
#   'but',
#   'alleras',
#   'had',
#   'been',
#   'buying',
#   'to',
#   'celebrate',
#   'his',
#   'copper',
#   'link',
#   'and',
#   'guilt',
#   'had',
#   'made',
#   'him',
#   'thirstybut',
#   'it',
#   'almost',
#   'sounded',
#   'as',
#   'if',
#   'the',
#   'nightingale',
#   'were',
#   'trilling',
#   'gold',
#   'for',
#   'iron',
#   'gold',
#   'for',
#   'iron',
#   'gold',
#   'for',
#   'iron'],
#  ['which',
#   'was',
#   'passing',
#   'strange',
#   'because',
#   'that',
#   'was',
#   'what',
#   'the',
#   'stranger',
#   'had',
#   'said',
#   'the',
#   'night',
#   'rosey',
#   'brought',
#   'the',
#   'two',
#   'of',
#   'them',
#   'together'],
#  ['who', 'are', 'you'],
#  ['pate',
#   'had',
#   'demanded',
#   'of',
#   'him',
#   'and',
#   'the',
#   'man',
#   'had',
#   'replied',
#   'an',
#   'alchemist'],
#  ['can', 'change', 'iron', 'into', 'gold'],
#  ['and',
#   'then',
#   'the',
#   'coin',
#   'was',
#   'in',
#   'his',
#   'hand',
#   'dancing',
#   'across',
#   'his',
#   'knuckles',
#   'the',
#   'soft',
#   'yellow',
#   'gold',
#   'shining',
#   'in',
#   'the',
#   'candlelight'],
#  ['on',
#   'one',
#   'side',
#   'was',
#   'three',
#   'headed',
#   'dragon',
#   'on',
#   'the',
#   'other',
#   'the',
#   'head',
#   'of',
#   'some',
#   'dead',
#   'king'],
#  ['gold', 'for', 'iron', 'pate', 'remembered', 'you', 'wont', 'do', 'better'],
#  ['do', 'you', 'want', 'her'],
#  ['do', 'you', 'love', 'her'],
#  ['am',
#   'no',
#   'thief',
#   'he',
#   'had',
#   'told',
#   'the',
#   'man',
#   'who',
#   'called',
#   'himself',
#   'the',
#   'alchemist',
#   'am',
#   'novice',
#   'of',
#   'the',
#   'citadel'],
#  ['the',
#   'alchemist',
#   'had',
#   'bowed',
#   'his',
#   'head',
#   'and',
#   'said',
#   'if',
#   'you',
#   'should',
#   'reconsider',
#   'shall',
#   'return',
#   'here',
#   'three',
#   'days',
#   'hence',
#   'with',
#   'my',
#   'dragon'],
#  ['three', 'days', 'had', 'passed'],
#  ['pate',
#   'had',
#   'returned',
#   'to',
#   'the',
#   'quill',
#   'and',
#   'tankard',
#   'still',
#   'uncertain',
#   'what',
#   'he',
#   'was',
#   'but',
#   'instead',
#   'of',
#   'the',
#   'alchemist',
#   'hed',
#   'found',
#   'mollander',
#   'and',
#   'armen',
#   'and',
#   'the',
#   'sphinx',
#   'with',
#   'roone',
#   'in',
#   'tow'],
#  ['it', 'would', 'have', 'raised', 'suspicions', 'not', 'to', 'join', 'them'],
#  ['the', 'quill', 'and', 'tankard', 'never', 'closed'],
#  ['for',
#   'six',
#   'hundred',
#   'years',
#   'it',
#   'had',
#   'been',
#   'standing',
#   'on',
#   'its',
#   'island',
#   'in',
#   'the',
#   'honeywine',
#   'and',
#   'never',
#   'once',
#   'had',
#   'its',
#   'doors',
#   'been',
#   'shut',
#   'to',
#   'trade'],
#  ['though',
#   'the',
#   'tall',
#   'timbered',
#   'building',
#   'leaned',
#   'toward',
#   'the',
#   'south',
#   'the',
#   'way',
#   'novices',
#   'sometimes',
#   'leaned',
#   'after',
#   'tankard',
#   'pate',
#   'expected',
#   'that',
#   'the',
#   'inn',
#   'would',
#   'go',
#   'on',
#   'standing',
#   'for',
#   'another',
#   'six',
#   'hundred',
#   'years',
#   'selling',
#   'wine',
#   'and',
#   'ale',
#   'and',
#   'fearsomely',
#   'strong',
#   'cider',
#   'to',
#   'rivermen',
#   'and',
#   'seamen',
#   'smiths',
#   'and',
#   'singers',
#   'priests',
#   'and',
#   'princes',
#   'and',
#   'the',
#   'novices',
#   'and',
#   'acolytes',
#   'of',
#   'the',
#   'citadel'],
#  ['oldtown',
#   'is',
#   'not',
#   'the',
#   'world',
#   'declared',
#   'mollander',
#   'too',
#   'loudly'],
#  ['he', 'was', 'knights', 'son', 'and', 'drunk', 'as', 'drunk', 'could', 'be'],
#  ['since',
#   'they',
#   'brought',
#   'him',
#   'word',
#   'of',
#   'his',
#   'fathers',
#   'death',
#   'upon',
#   'the',
#   'blackwater',
#   'he',
#   'got',
#   'drunk',
#   'most',
#   'every',
#   'night'],
#  ['even',
#   'in',
#   'oldtown',
#   'far',
#   'from',
#   'the',
#   'fighting',
#   'and',
#   'safe',
#   'behind',
#   'its',
#   'walls',
#   'the',
#   'war',
#   'of',
#   'the',
#   'five',
#   'kings',
#   'had',
#   'touched',
#   'them',
#   'all',
#   'although',
#   'archmaester',
#   'benedict',
#   'insisted',
#   'that',
#   'there',
#   'had',
#   'never',
#   'been',
#   'war',
#   'of',
#   'five',
#   'kings',
#   'since',
#   'renly',
#   'baratheon',
#   'had',
#   'been',
#   'slain',
#   'before',
#   'balon',
#   'greyjoy',
#   'had',
#   'crowned',
#   'himself'],
#  ['my',
#   'father',
#   'always',
#   'said',
#   'the',
#   'world',
#   'was',
#   'bigger',
#   'than',
#   'any',
#   'lords',
#   'castle',
#   'mollander',
#   'went',
#   'on'],
#  ['dragons',
#   'must',
#   'be',
#   'the',
#   'least',
#   'of',
#   'the',
#   'things',
#   'man',
#   'might',
#   'find',
#   'in',
#   'qarth',
#   'and',
#   'asshai',
#   'and',
#   'yi',
#   'ti'],
#  ['these',
#   'sailors',
#   'stories',
#   'are',
#   'stories',
#   'told',
#   'by',
#   'sailors',
#   'armen',
#   'interrupted'],
#  ['sailors', 'my', 'dear', 'mollander'],
#  ['go',
#   'back',
#   'down',
#   'to',
#   'the',
#   'docks',
#   'and',
#   'wager',
#   'youll',
#   'find',
#   'sailors',
#   'wholl',
#   'tell',
#   'you',
#   'of',
#   'the',
#   'mermaids',
#   'that',
#   'they',
#   'bedded',
#   'or',
#   'how',
#   'they',
#   'spent',
#   'year',
#   'in',
#   'the',
#   'belly',
#   'of',
#   'fish'],
#  ['how', 'do', 'you', 'know', 'they', 'didnt'],
#  ['mollander',
#   'thumped',
#   'through',
#   'the',
#   'grass',
#   'looking',
#   'for',
#   'more',
#   'apples'],
#  ['youd',
#   'need',
#   'to',
#   'be',
#   'down',
#   'the',
#   'belly',
#   'yourself',
#   'to',
#   'swear',
#   'they',
#   'werent'],
#  ['one',
#   'sailor',
#   'with',
#   'story',
#   'aye',
#   'man',
#   'might',
#   'laugh',
#   'at',
#   'that',
#   'but',
#   'when',
#   'oarsmen',
#   'off',
#   'four',
#   'different',
#   'ships',
#   'tell',
#   'the',
#   'same',
#   'tale',
#   'in',
#   'four',
#   'different',
#   'tongues'],
#  ['the', 'tales', 'are', 'not', 'the', 'same', 'insisted', 'armen'],
#  ['dragons',
#   'in',
#   'asshai',
#   'dragons',
#   'in',
#   'qarth',
#   'dragons',
#   'in',
#   'meereen',
#   'dothraki',
#   'dragons',
#   'dragons',
#   'freeing',
#   'slaves',
#   'each',
#   'telling',
#   'differs',
#   'from',
#   'the',
#   'last'],
#  ['only', 'in', 'details'],
#  ['mollander',
#   'grew',
#   'more',
#   'stubborn',
#   'when',
#   'he',
#   'drank',
#   'and',
#   'even',
#   'when',
#   'sober',
#   'he',
#   'was',
#   'bullheaded'],
#  ['all', 'speak', 'of', 'dragons', 'and', 'beautiful', 'young', 'queen'],
#  ['the',
#   'only',
#   'dragon',
#   'pate',
#   'cared',
#   'about',
#   'was',
#   'made',
#   'of',
#   'yellow',
#   'gold'],
#  ['he', 'wondered', 'what', 'had', 'happened', 'to', 'the', 'alchemist'],
#  ['the', 'third', 'day'],
#  ['he', 'said', 'hed', 'be', 'here'],
#  ['theres',
#   'another',
#   'apple',
#   'near',
#   'your',
#   'foot',
#   'alleras',
#   'called',
#   'to',
#   'mollander',
#   'and',
#   'still',
#   'have',
#   'two',
#   'arrows',
#   'in',
#   'my',
#   'quiver'],
#  ['fuck', 'your', 'quiver'],
#  ['mollander', 'scooped', 'up', 'the', 'windfall'],
#  ['this',
#   'ones',
#   'wormy',
#   'he',
#   'complained',
#   'but',
#   'he',
#   'threw',
#   'it',
#   'anyway'],
#  ['the',
#   'arrow',
#   'caught',
#   'the',
#   'apple',
#   'as',
#   'it',
#   'began',
#   'to',
#   'fall',
#   'and',
#   'sliced',
#   'it',
#   'clean',
#   'in',
#   'two'],
#  ['one',
#   'half',
#   'landed',
#   'on',
#   'turret',
#   'roof',
#   'tumbled',
#   'to',
#   'lower',
#   'roof',
#   'bounced',
#   'and',
#   'missed',
#   'armen',
#   'by',
#   'foot'],
#  ['if',
#   'you',
#   'cut',
#   'worm',
#   'in',
#   'two',
#   'you',
#   'make',
#   'two',
#   'worms',
#   'the',
#   'acolyte',
#   'informed',
#   'them'],
#  ['if',
#   'only',
#   'it',
#   'worked',
#   'that',
#   'way',
#   'with',
#   'apples',
#   'no',
#   'one',
#   'would',
#   'ever',
#   'need',
#   'go',
#   'hungry',
#   'said',
#   'alleras',
#   'with',
#   'one',
#   'of',
#   'his',
#   'soft',
#   'smiles'],
#  ['the',
#   'sphinx',
#   'was',
#   'always',
#   'smiling',
#   'as',
#   'if',
#   'he',
#   'knew',
#   'some',
#   'secret',
#   'jape'],
#  ['it',
#   'gave',
#   'him',
#   'wicked',
#   'look',
#   'that',
#   'went',
#   'well',
#   'with',
#   'his',
#   'pointed',
#   'chin',
#   'widows',
#   'peak',
#   'and',
#   'dense',
#   'mat',
#   'of',
#   'close',
#   'cropped',
#   'jet',
#   'black',
#   'curls'],
#  ['alleras', 'would', 'make', 'maester'],
#  ['he',
#   'had',
#   'only',
#   'been',
#   'at',
#   'the',
#   'citadel',
#   'for',
#   'year',
#   'yet',
#   'already',
#   'he',
#   'had',
#   'forged',
#   'three',
#   'links',
#   'of',
#   'his',
#   'maesters',
#   'chain'],
#  ['armen',
#   'might',
#   'have',
#   'more',
#   'but',
#   'each',
#   'of',
#   'his',
#   'had',
#   'taken',
#   'him',
#   'year',
#   'to',
#   'earn'],
#  ['still', 'he', 'would', 'make', 'maester', 'too'],
#  ['roone',
#   'and',
#   'mollander',
#   'remained',
#   'pink',
#   'necked',
#   'novices',
#   'but',
#   'roone',
#   'was',
#   'very',
#   'young',
#   'and',
#   'mollander',
#   'preferred',
#   'drinking',
#   'to',
#   'reading'],
#  ['pate', 'though'],
#  ['he',
#   'had',
#   'been',
#   'five',
#   'years',
#   'at',
#   'the',
#   'citadel',
#   'arriving',
#   'when',
#   'he',
#   'was',
#   'no',
#   'more',
#   'than',
#   'three',
#   'and',
#   'ten',
#   'yet',
#   'his',
#   'neck',
#   'remained',
#   'as',
#   'pink',
#   'as',
#   'it',
#   'had',
#   'been',
#   'on',
#   'the',
#   'day',
#   'he',
#   'first',
#   'arrived',
#   'from',
#   'the',
#   'westerlands'],
#  ['twice', 'had', 'he', 'believed', 'himself', 'ready'],
#  ['the',
#   'first',
#   'time',
#   'he',
#   'had',
#   'gone',
#   'before',
#   'archmaester',
#   'vaellyn',
#   'to',
#   'demonstrate',
#   'his',
#   'knowledge',
#   'of',
#   'the',
#   'heavens'],
#  ['instead',
#   'he',
#   'learned',
#   'how',
#   'vinegar',
#   'vaellyn',
#   'had',
#   'earned',
#   'that',
#   'name'],
#  ['it',
#   'took',
#   'pate',
#   'two',
#   'years',
#   'to',
#   'summon',
#   'up',
#   'the',
#   'courage',
#   'to',
#   'try',
#   'again'],
#  ['this',
#   'time',
#   'he',
#   'submitted',
#   'himself',
#   'to',
#   'kindly',
#   'old',
#   'archmaester',
#   'ebrose',
#   'renowned',
#   'for',
#   'his',
#   'soft',
#   'voice',
#   'and',
#   'gentle',
#   'hands',
#   'but',
#   'ebroses',
#   'sighs',
#   'had',
#   'somehow',
#   'proved',
#   'just',
#   'as',
#   'painful',
#   'as',
#   'vaellyns',
#   'barbs'],
#  ['one',
#   'last',
#   'apple',
#   'promised',
#   'alleras',
#   'and',
#   'will',
#   'tell',
#   'you',
#   'what',
#   'suspect',
#   'about',
#   'these',
#   'dragons'],
#  ['what', 'could', 'you', 'know', 'that', 'dont'],
#  ['grumbled', 'mollander'],
#  ['he',
#   'spied',
#   'an',
#   'apple',
#   'on',
#   'branch',
#   'jumped',
#   'up',
#   'pulled',
#   'it',
#   'down',
#   'and',
#   'threw'],
#  ['alleras',
#   'drew',
#   'his',
#   'bowstring',
#   'back',
#   'to',
#   'his',
#   'ear',
#   'turning',
#   'gracefully',
#   'to',
#   'follow',
#   'the',
#   'target',
#   'in',
#   'flight'],
#  ['he',
#   'loosed',
#   'his',
#   'shaft',
#   'just',
#   'as',
#   'the',
#   'apple',
#   'began',
#   'to',
#   'fall'],
#  ['you', 'always', 'miss', 'your', 'last', 'shot', 'said', 'roone'],
#  ['the', 'apple', 'splashed', 'down', 'into', 'the', 'river', 'untouched'],
#  ['see'],
#  ['said', 'roone'],
#  ['the',
#   'day',
#   'you',
#   'make',
#   'them',
#   'all',
#   'is',
#   'the',
#   'day',
#   'you',
#   'stop',
#   'improving'],
#  ['alleras',
#   'unstrung',
#   'his',
#   'longbow',
#   'and',
#   'eased',
#   'it',
#   'into',
#   'its',
#   'leather',
#   'case'],
#  ['the',
#   'bow',
#   'was',
#   'carved',
#   'from',
#   'goldenheart',
#   'rare',
#   'and',
#   'fabled',
#   'wood',
#   'from',
#   'the',
#   'summer',
#   'isles'],
#  ['pate', 'had', 'tried', 'to', 'bend', 'it', 'once', 'and', 'failed'],
#  ['the',
#   'sphinx',
#   'looks',
#   'slight',
#   'but',
#   'theres',
#   'strength',
#   'in',
#   'those',
#   'slim',
#   'arms',
#   'he',
#   'reflected',
#   'as',
#   'alleras',
#   'threw',
#   'leg',
#   'across',
#   'the',
#   'bench',
#   'and',
#   'reached',
#   'for',
#   'his',
#   'wine',
#   'cup'],
#  ['the',
#   'dragon',
#   'has',
#   'three',
#   'heads',
#   'he',
#   'announced',
#   'in',
#   'his',
#   'soft',
#   'dornish',
#   'drawl'],
#  ['is', 'this', 'riddle'],
#  ['roone', 'wanted', 'to', 'know'],
#  ['sphinxes', 'always', 'speak', 'in', 'riddles', 'in', 'the', 'tales'],
#  ['no', 'riddle'],
#  ['alleras', 'sipped', 'his', 'wine'],
#  ['the',
#   'rest',
#   'of',
#   'them',
#   'were',
#   'quaffing',
#   'tankards',
#   'of',
#   'the',
#   'fearsomely',
#   'strong',
#   'cider',
#   'that',
#   'the',
#   'quill',
#   'and',
#   'tankard',
#   'was',
#   'renowned',
#   'for',
#   'but',
#   'he',
#   'preferred',
#   'the',
#   'strange',
#   'sweet',
#   'wines',
#   'of',
#   'his',
#   'mothers',
#   'country'],
#  ['even', 'in', 'oldtown', 'such', 'wines', 'did', 'not', 'come', 'cheap'],
#  ['it',
#   'had',
#   'been',
#   'lazy',
#   'leo',
#   'who',
#   'dubbed',
#   'alleras',
#   'the',
#   'sphinx'],
#  ['sphinx',
#   'is',
#   'bit',
#   'of',
#   'this',
#   'bit',
#   'of',
#   'that',
#   'human',
#   'face',
#   'the',
#   'body',
#   'of',
#   'lion',
#   'the',
#   'wings',
#   'of',
#   'hawk'],
#  ['alleras',
#   'was',
#   'the',
#   'same',
#   'his',
#   'father',
#   'was',
#   'dornishman',
#   'his',
#   'mother',
#   'black',
#   'skinned',
#   'summer',
#   'islander'],
#  ['his', 'own', 'skin', 'was', 'dark', 'as', 'teak'],
#  ['and',
#   'like',
#   'the',
#   'green',
#   'marble',
#   'sphinxes',
#   'that',
#   'flanked',
#   'the',
#   'citadels',
#   'main',
#   'gate',
#   'alleras',
#   'had',
#   'eyes',
#   'of',
#   'onyx'],
#  ['no',
#   'dragon',
#   'has',
#   'ever',
#   'had',
#   'three',
#   'heads',
#   'except',
#   'on',
#   'shields',
#   'and',
#   'banners',
#   'armen',
#   'the',
#   'acolyte',
#   'said',
#   'firmly'],
#  ['that', 'was', 'heraldic', 'charge', 'no', 'more'],
#  ['furthermore', 'the', 'targaryens', 'are', 'all', 'dead'],
#  ['not', 'all', 'said', 'alleras'],
#  ['the', 'beggar', 'king', 'had', 'sister'],
#  ['thought',
#   'her',
#   'head',
#   'was',
#   'smashed',
#   'against',
#   'wall',
#   'said',
#   'roone'],
#  ['no', 'said', 'alleras'],
#  ['it',
#   'was',
#   'prince',
#   'rhaegars',
#   'young',
#   'son',
#   'aegon',
#   'whose',
#   'head',
#   'was',
#   'dashed',
#   'against',
#   'the',
#   'wall',
#   'by',
#   'the',
#   'lion',
#   'of',
#   'lannisters',
#   'brave',
#   'men'],
#  ['we',
#   'speak',
#   'of',
#   'rhaegars',
#   'sister',
#   'born',
#   'on',
#   'dragonstone',
#   'before',
#   'its',
#   'fall'],
#  ['the', 'one', 'they', 'called', 'daenerys'],
#  ['the', 'stormborn'],
#  ['recall', 'her', 'now'],
#  ['mollander',
#   'lifted',
#   'his',
#   'tankard',
#   'high',
#   'sloshing',
#   'the',
#   'cider',
#   'that',
#   'remained'],
#  ['heres', 'to', 'her'],
#  ['he',
#   'gulped',
#   'slammed',
#   'his',
#   'empty',
#   'tankard',
#   'down',
#   'belched',
#   'and',
#   'wiped',
#   'his',
#   'mouth',
#   'with',
#   'the',
#   'back',
#   'of',
#   'his',
#   'hand'],
#  ['wheres', 'rosey'],
#  ['our',
#   'rightful',
#   'queen',
#   'deserves',
#   'another',
#   'round',
#   'of',
#   'cider',
#   'wouldnt',
#   'you',
#   'say'],
#  ['armen', 'the', 'acolyte', 'looked', 'alarmed'],
#  ['lower', 'your', 'voice', 'fool'],
#  ['you', 'should', 'not', 'even', 'jape', 'about', 'such', 'things'],
#  ['you', 'never', 'know', 'who', 'could', 'be', 'listening'],
#  ['the', 'spider', 'has', 'ears', 'everywhere'],
#  ['ah', 'dont', 'piss', 'your', 'breeches', 'armen'],
#  ['was', 'proposing', 'drink', 'not', 'rebellion'],
#  ['pate', 'heard', 'chuckle'],
#  ['soft', 'sly', 'voice', 'called', 'out', 'from', 'behind', 'him'],
#  ['always', 'knew', 'you', 'were', 'traitor', 'hopfrog'],
#  ['lazy',
#   'leo',
#   'was',
#   'slouching',
#   'by',
#   'the',
#   'foot',
#   'of',
#   'the',
#   'old',
#   'plank',
#   'bridge',
#   'draped',
#   'in',
#   'satin',
#   'striped',
#   'in',
#   'green',
#   'and',
#   'gold',
#   'with',
#   'black',
#   'silk',
#   'half',
#   'cape',
#   'pinned',
#   'to',
#   'his',
#   'shoulder',
#   'by',
#   'rose',
#   'of',
#   'jade'],
#  ['the',
#   'wine',
#   'hed',
#   'dribbled',
#   'down',
#   'his',
#   'front',
#   'had',
#   'been',
#   'robust',
#   'red',
#   'judging',
#   'from',
#   'the',
#   'color',
#   'of',
#   'the',
#   'spots'],
#  ['lock',
#   'of',
#   'his',
#   'ash',
#   'blond',
#   'hair',
#   'fell',
#   'down',
#   'across',
#   'one',
#   'eye'],
#  ['mollander', 'bristled', 'at', 'the', 'sight', 'of', 'him'],
#  ['bugger', 'that'],
#  ['go', 'away'],
#  ['you', 'are', 'not', 'welcome', 'here'],
#  ['alleras',
#   'laid',
#   'hand',
#   'upon',
#   'his',
#   'arm',
#   'to',
#   'calm',
#   'him',
#   'whilst',
#   'armen',
#   'frowned'],
#  ['leo'],
#  ['my', 'lord'],
#  ['had',
#   'understood',
#   'that',
#   'you',
#   'were',
#   'still',
#   'confined',
#   'to',
#   'the',
#   'citadel',
#   'for',
#   'three',
#   'more',
#   'days'],
#  ['lazy', 'leo', 'shrugged'],
#  ['perestan',
#   'says',
#   'the',
#   'world',
#   'is',
#   'forty',
#   'thousand',
#   'years',
#   'old'],
#  ['mollos', 'says', 'five', 'hundred', 'thousand'],
#  ['what', 'are', 'three', 'days', 'ask', 'you'],
#  ['though',
#   'there',
#   'were',
#   'dozen',
#   'empty',
#   'tables',
#   'on',
#   'the',
#   'terrace',
#   'leo',
#   'sat',
#   'himself',
#   'at',
#   'theirs'],
#  ['buy',
#   'me',
#   'cup',
#   'of',
#   'arbor',
#   'gold',
#   'hopfrog',
#   'and',
#   'perhaps',
#   'wont',
#   'inform',
#   'my',
#   'father',
#   'of',
#   'your',
#   'toast'],
#  ['the',
#   'tiles',
#   'turned',
#   'against',
#   'me',
#   'at',
#   'the',
#   'checkered',
#   'hazard',
#   'and',
#   'wasted',
#   'my',
#   'last',
#   'stag',
#   'on',
#   'supper'],
#  ['suckling',
#   'pig',
#   'in',
#   'plum',
#   'sauce',
#   'stuffed',
#   'with',
#   'chestnuts',
#   'and',
#   'white',
#   'truffles'],
#  ['man', 'must', 'eat'],
#  ['what', 'did', 'you', 'lads', 'have'],
#  ['mutton', 'muttered', 'mollander'],
#  ['he', 'sounded', 'none', 'too', 'pleased', 'about', 'it'],
#  ['we', 'shared', 'haunch', 'of', 'boiled', 'mutton'],
#  ['im', 'certain', 'it', 'was', 'filling'],
#  ['leo', 'turned', 'to', 'alleras'],
#  ['lords', 'son', 'should', 'be', 'open', 'handed', 'sphinx'],
#  ['understand', 'you', 'won', 'your', 'copper', 'link'],
#  ['ill', 'drink', 'to', 'that'],
#  ['alleras', 'smiled', 'back', 'at', 'him'],
#  ['only', 'buy', 'for', 'friends'],
#  ['and', 'am', 'no', 'lords', 'son', 'ive', 'told', 'you', 'that'],
#  ['my', 'mother', 'was', 'trader'],
#  ['leos', 'eyes', 'were', 'hazel', 'bright', 'with', 'wine', 'and', 'malice'],
#  ['your', 'mother', 'was', 'monkey', 'from', 'the', 'summer', 'isles'],
#  ['the',
#   'dornish',
#   'will',
#   'fuck',
#   'anything',
#   'with',
#   'hole',
#   'between',
#   'its',
#   'legs'],
#  ['meaning', 'no', 'offense'],
#  ['you',
#   'may',
#   'be',
#   'brown',
#   'as',
#   'nut',
#   'but',
#   'at',
#   'least',
#   'you',
#   'bathe'],
#  ['unlike', 'our', 'spotted', 'pig', 'boy'],
#  ['he', 'waved', 'hand', 'toward', 'pate'],
#  ['if',
#   'hit',
#   'him',
#   'in',
#   'the',
#   'mouth',
#   'with',
#   'my',
#   'tankard',
#   'could',
#   'knock',
#   'out',
#   'half',
#   'his',
#   'teeth',
#   'pate',
#   'thought'],
#  ['spotted',
#   'pate',
#   'the',
#   'pig',
#   'boy',
#   'was',
#   'the',
#   'hero',
#   'of',
#   'thousand',
#   'ribald',
#   'stories',
#   'good',
#   'hearted',
#   'empty',
#   'headed',
#   'lout',
#   'who',
#   'always',
#   'managed',
#   'to',
#   'best',
#   'the',
#   'fat',
#   'lordlings',
#   'haughty',
#   'knights',
#   'and',
#   'pompous',
#   'septons',
#   'who',
#   'beset',
#   'him'],
#  ['somehow',
#   'his',
#   'stupidity',
#   'would',
#   'turn',
#   'out',
#   'to',
#   'have',
#   'been',
#   'sort',
#   'of',
#   'uncouth',
#   'cunning',
#   'the',
#   'tales',
#   'always',
#   'ended',
#   'with',
#   'spotted',
#   'pate',
#   'sitting',
#   'on',
#   'lords',
#   'high',
#   'seat',
#   'or',
#   'bedding',
#   'some',
#   'knights',
#   'daughter'],
#  ['but', 'those', 'were', 'stories'],
#  ['in', 'the', 'real', 'world', 'pig', 'boys', 'never', 'fared', 'so', 'well'],
#  ['pate',
#   'sometimes',
#   'thought',
#   'his',
#   'mother',
#   'must',
#   'have',
#   'hated',
#   'him',
#   'to',
#   'have',
#   'named',
#   'him',
#   'as',
#   'she',
#   'did'],
#  ['alleras', 'was', 'no', 'longer', 'smiling'],
#  ['you', 'will', 'apologize'],
#  ['will'],
#  ['said', 'leo'],
#  ['how',
#   'can',
#   'with',
#   'my',
#   'throat',
#   'so',
#   'dry',
#   'you',
#   'shame',
#   'your',
#   'house',
#   'with',
#   'every',
#   'word',
#   'you',
#   'say',
#   'alleras',
#   'told',
#   'him'],
#  ['you', 'shame', 'the', 'citadel', 'by', 'being', 'one', 'of', 'us'],
#  ['know'],
#  ['so', 'buy', 'me', 'some', 'wine', 'that', 'might', 'drown', 'my', 'shame'],
#  ['mollander',
#   'said',
#   'would',
#   'tear',
#   'your',
#   'tongue',
#   'out',
#   'by',
#   'the',
#   'roots'],
#  ['truly'],
#  ['then', 'how', 'would', 'tell', 'you', 'about', 'the', 'dragons'],
#  ['leo', 'shrugged', 'again'],
#  ['the', 'mongrel', 'has', 'the', 'right', 'of', 'it'],
#  ['the',
#   'mad',
#   'kings',
#   'daughter',
#   'is',
#   'alive',
#   'and',
#   'shes',
#   'hatched',
#   'herself',
#   'three',
#   'dragons'],
#  ['three'],
#  ['said', 'roone', 'astonished'],
#  ['leo', 'patted', 'his', 'hand'],
#  ['more', 'than', 'two', 'and', 'less', 'than', 'four'],
#  ['would',
#   'not',
#   'try',
#   'for',
#   'my',
#   'golden',
#   'link',
#   'just',
#   'yet',
#   'if',
#   'were',
#   'you'],
#  ['you', 'leave', 'him', 'be', 'warned', 'mollander'],
#  ['such', 'chivalrous', 'hopfrog'],
#  ['as', 'you', 'wish'],
#  ['every',
#   'man',
#   'off',
#   'every',
#   'ship',
#   'thats',
#   'sailed',
#   'within',
#   'hundred',
#   'leagues',
#   'of',
#   'qarth',
#   'is',
#   'speaking',
#   'of',
#   'these',
#   'dragons'],
#  ['few', 'will', 'even', 'tell', 'you', 'that', 'theyve', 'seen', 'them'],
#  ['the', 'mage', 'is', 'inclined', 'to', 'believe', 'them'],
#  ['armen', 'pursed', 'his', 'lips', 'in', 'disapproval'],
#  ['marwyn', 'is', 'unsound'],
#  ['archmaester',
#   'perestan',
#   'would',
#   'be',
#   'the',
#   'first',
#   'to',
#   'tell',
#   'you',
#   'that'],
#  ['archmaester', 'ryam', 'says', 'so', 'too', 'said', 'roone'],
#  ['leo', 'yawned'],
#  ['the',
#   'sea',
#   'is',
#   'wet',
#   'the',
#   'sun',
#   'is',
#   'warm',
#   'and',
#   'the',
#   'menagerie',
#   'hates',
#   'the',
#   'mastiff'],
#  ['he',
#   'has',
#   'mocking',
#   'name',
#   'for',
#   'everyone',
#   'thought',
#   'pate',
#   'but',
#   'he',
#   'could',
#   'not',
#   'deny',
#   'that',
#   'marwyn',
#   'looked',
#   'more',
#   'mastiff',
#   'than',
#   'maester'],
#  ['as', 'if', 'he', 'wants', 'to', 'bite', 'you'],
#  ['the', 'mage', 'was', 'not', 'like', 'other', 'maesters'],
#  ['people',
#   'said',
#   'that',
#   'he',
#   'kept',
#   'company',
#   'with',
#   'whores',
#   'and',
#   'hedge',
#   'wizards',
#   'talked',
#   'with',
#   'hairy',
#   'ibbenese',
#   'and',
#   'pitch',
#   'black',
#   'summer',
#   'islanders',
#   'in',
#   'their',
#   'own',
#   'tongues',
#   'and',
#   'sacrificed',
#   'to',
#   'queer',
#   'gods',
#   'at',
#   'the',
#   'little',
#   'sailors',
#   'temples',
#   'down',
#   'by',
#   'the',
#   'wharves'],
#  ['men',
#   'spoke',
#   'of',
#   'seeing',
#   'him',
#   'down',
#   'in',
#   'the',
#   'undercity',
#   'in',
#   'rat',
#   'pits',
#   'and',
#   'black',
#   'brothels',
#   'consorting',
#   'with',
#   'mummers',
#   'singers',
#   'sellswords',
#   'even',
#   'beggars'],
#  ['some',
#   'even',
#   'whispered',
#   'that',
#   'once',
#   'he',
#   'had',
#   'killed',
#   'man',
#   'with',
#   'his',
#   'fists'],
#  ['when',
#   'marwyn',
#   'had',
#   'returned',
#   'to',
#   'oldtown',
#   'after',
#   'spending',
#   'eight',
#   'years',
#   'in',
#   'the',
#   'east',
#   'mapping',
#   'distant',
#   'lands',
#   'searching',
#   'for',
#   'lost',
#   'books',
#   'and',
#   'studying',
#   'with',
#   'warlocks',
#   'and',
#   'shadowbinders',
#   'vinegar',
#   'vaellyn',
#   'had',
#   'dubbed',
#   'him',
#   'marwyn',
#   'the',
#   'mage'],
#  ['the',
#   'name',
#   'was',
#   'soon',
#   'all',
#   'over',
#   'oldtown',
#   'to',
#   'vaellyns',
#   'vast',
#   'annoyance'],
#  ['leave',
#   'spells',
#   'and',
#   'prayers',
#   'to',
#   'priests',
#   'and',
#   'septons',
#   'and',
#   'bend',
#   'your',
#   'wits',
#   'to',
#   'learning',
#   'truths',
#   'man',
#   'can',
#   'trust',
#   'in',
#   'archmaester',
#   'ryam',
#   'had',
#   'once',
#   'counseled',
#   'pate',
#   'but',
#   'ryams',
#   'ring',
#   'and',
#   'rod',
#   'and',
#   'mask',
#   'were',
#   'yellow',
#   'gold',
#   'and',
#   'his',
#   'maesters',
#   'chain',
#   'had',
#   'no',
#   'link',
#   'of',
#   'valyrian',
#   'steel'],
#  ['armen', 'looked', 'down', 'his', 'nose', 'at', 'lazy', 'leo'],
#  ['he',
#   'had',
#   'the',
#   'perfect',
#   'nose',
#   'for',
#   'it',
#   'long',
#   'and',
#   'thin',
#   'and',
#   'pointed'],
#  ['archmaester',
#   'marwyn',
#   'believes',
#   'in',
#   'many',
#   'curious',
#   'things',
#   'he',
#   'said',
#   'but',
#   'he',
#   'has',
#   'no',
#   'more',
#   'proof',
#   'of',
#   'dragons',
#   'than',
#   'mollander'],
#  ['just', 'more', 'sailors', 'stories'],
#  ['youre', 'wrong', 'said', 'leo'],
#  ['there',
#   'is',
#   'glass',
#   'candle',
#   'burning',
#   'in',
#   'the',
#   'mages',
#   'chambers'],
#  ['hush', 'fell', 'over', 'the', 'torchlit', 'terrace'],
#  ['armen', 'sighed', 'and', 'shook', 'his', 'head'],
#  ['mollander', 'began', 'to', 'laugh'],
#  ['the', 'sphinx', 'studied', 'leo', 'with', 'his', 'big', 'black', 'eyes'],
#  ['roone', 'looked', 'lost'],
#  ['pate',
#   'knew',
#   'about',
#   'the',
#   'glass',
#   'candles',
#   'though',
#   'he',
#   'had',
#   'never',
#   'seen',
#   'one',
#   'burn'],
#  ['they', 'were', 'the', 'worst', 'kept', 'secret', 'of', 'the', 'citadel'],
#  ['it',
#   'was',
#   'said',
#   'that',
#   'they',
#   'had',
#   'been',
#   'brought',
#   'to',
#   'oldtown',
#   'from',
#   'valyria',
#   'thousand',
#   'years',
#   'before',
#   'the',
#   'doom'],
#  ['he',
#   'had',
#   'heard',
#   'there',
#   'were',
#   'four',
#   'one',
#   'was',
#   'green',
#   'and',
#   'three',
#   'were',
#   'black',
#   'and',
#   'all',
#   'were',
#   'tall',
#   'and',
#   'twisted'],
#  ['what', 'are', 'these', 'glass', 'candles'],
#  ['asked', 'roone'],
#  ['armen', 'the', 'acolyte', 'cleared', 'his', 'throat'],
#  ['the',
#   'night',
#   'before',
#   'an',
#   'acolyte',
#   'says',
#   'his',
#   'vows',
#   'he',
#   'must',
#   'stand',
#   'vigil',
#   'in',
#   'the',
#   'vault'],
#  ['no',
#   'lantern',
#   'is',
#   'permitted',
#   'him',
#   'no',
#   'torch',
#   'no',
#   'lamp',
#   'no',
#   'taper',
#   'only',
#   'candle',
#   'of',
#   'obsidian'],
#  ['he',
#   'must',
#   'spend',
#   'the',
#   'night',
#   'in',
#   'darkness',
#   'unless',
#   'he',
#   'can',
#   'light',
#   'that',
#   'candle'],
#  ['some', 'will', 'try'],
#  ['the',
#   'foolish',
#   'and',
#   'the',
#   'stubborn',
#   'those',
#   'who',
#   'have',
#   'made',
#   'study',
#   'of',
#   'these',
#   'so',
#   'called',
#   'higher',
#   'mysteries'],
#  ['often',
#   'they',
#   'cut',
#   'their',
#   'fingers',
#   'for',
#   'the',
#   'ridges',
#   'on',
#   'the',
#   'candles',
#   'are',
#   'said',
#   'to',
#   'be',
#   'as',
#   'sharp',
#   'as',
#   'razors'],
#  ['then',
#   'with',
#   'bloody',
#   'hands',
#   'they',
#   'must',
#   'wait',
#   'upon',
#   'the',
#   'dawn',
#   'brooding',
#   'on',
#   'their',
#   'failure'],
#  ['wiser',
#   'men',
#   'simply',
#   'go',
#   'to',
#   'sleep',
#   'or',
#   'spend',
#   'their',
#   'night',
#   'in',
#   'prayer',
#   'but',
#   'every',
#   'year',
#   'there',
#   'are',
#   'always',
#   'few',
#   'who',
#   'must',
#   'try'],
#  ['yes'],
#  ['pate', 'had', 'heard', 'the', 'same', 'stories'],
#  ['but',
#   'whats',
#   'the',
#   'use',
#   'of',
#   'candle',
#   'that',
#   'casts',
#   'no',
#   'light'],
#  ['it',
#   'is',
#   'lesson',
#   'armen',
#   'said',
#   'the',
#   'last',
#   'lesson',
#   'we',
#   'must',
#   'learn',
#   'before',
#   'we',
#   'don',
#   'our',
#   'maesters',
#   'chains'],
#  ['the',
#   'glass',
#   'candle',
#   'is',
#   'meant',
#   'to',
#   'represent',
#   'truth',
#   'and',
#   'learning',
#   'rare',
#   'and',
#   'beautiful',
#   'and',
#   'fragile',
#   'things'],
#  ['it',
#   'is',
#   'made',
#   'in',
#   'the',
#   'shape',
#   'of',
#   'candle',
#   'to',
#   'remind',
#   'us',
#   'that',
#   'maester',
#   'must',
#   'cast',
#   'light',
#   'wherever',
#   'he',
#   'serves',
#   'and',
#   'it',
#   'is',
#   'sharp',
#   'to',
#   'remind',
#   'us',
#   'that',
#   'knowledge',
#   'can',
#   'be',
#   'dangerous'],
#  ['wise',
#   'men',
#   'may',
#   'grow',
#   'arrogant',
#   'in',
#   'their',
#   'wisdom',
#   'but',
#   'maester',
#   'must',
#   'always',
#   'remain',
#   'humble'],
#  ['the', 'glass', 'candle', 'reminds', 'us', 'of', 'that', 'as', 'well'],
#  ['even',
#   'after',
#   'he',
#   'has',
#   'said',
#   'his',
#   'vow',
#   'and',
#   'donned',
#   'his',
#   'chain',
#   'and',
#   'gone',
#   'forth',
#   'to',
#   'serve',
#   'maester',
#   'will',
#   'think',
#   'back',
#   'on',
#   'the',
#   'darkness',
#   'of',
#   'his',
#   'vigil',
#   'and',
#   'remember',
#   'how',
#   'nothing',
#   'that',
#   'he',
#   'did',
#   'could',
#   'make',
#   'the',
#   'candle',
#   'burn',
#   'for',
#   'even',
#   'with',
#   'knowledge',
#   'some',
#   'things',
#   'are',
#   'not',
#   'possible'],
#  ['lazy', 'leo', 'burst', 'out', 'laughing'],
#  ['not', 'possible', 'for', 'you', 'you', 'mean'],
#  ['saw', 'the', 'candle', 'burning', 'with', 'my', 'own', 'eyes'],
#  ['you', 'saw', 'some', 'candle', 'burning', 'dont', 'doubt', 'said', 'armen'],
#  ['candle', 'of', 'black', 'wax', 'perhaps'],
#  ['know', 'what', 'saw'],
#  ['the',
#   'light',
#   'was',
#   'queer',
#   'and',
#   'bright',
#   'much',
#   'brighter',
#   'than',
#   'any',
#   'beeswax',
#   'or',
#   'tallow',
#   'candle'],
#  ['it',
#   'cast',
#   'strange',
#   'shadows',
#   'and',
#   'the',
#   'flame',
#   'never',
#   'flickered',
#   'not',
#   'even',
#   'when',
#   'draft',
#   'blew',
#   'through',
#   'the',
#   'open',
#   'door',
#   'behind',
#   'me'],
#  ['armen', 'crossed', 'his', 'arms'],
#  ['obsidian', 'does', 'not', 'burn'],
#  ['dragonglass', 'pate', 'said'],
#  ['the', 'smallfolk', 'call', 'it', 'dragonglass'],
#  ['somehow', 'that', 'seemed', 'important'],
#  ['they',
#   'do',
#   'mused',
#   'alleras',
#   'the',
#   'sphinx',
#   'and',
#   'if',
#   'there',
#   'are',
#   'dragons',
#   'in',
#   'the',
#   'world',
#   'again',
#   'dragons',
#   'and',
#   'darker',
#   'things',
#   'said',
#   'leo'],
#  ['the',
#   'grey',
#   'sheep',
#   'have',
#   'closed',
#   'their',
#   'eyes',
#   'but',
#   'the',
#   'mastiff',
#   'sees',
#   'the',
#   'truth'],
#  ['old', 'powers', 'waken'],
#  ['shadows', 'stir'],
#  ['an',
#   'age',
#   'of',
#   'wonder',
#   'and',
#   'terror',
#   'will',
#   'soon',
#   'be',
#   'upon',
#   'us',
#   'an',
#   'age',
#   'for',
#   'gods',
#   'and',
#   'heroes'],
#  ['he', 'stretched', 'smiling', 'his', 'lazy', 'smile'],
#  ['thats', 'worth', 'round', 'id', 'say'],
#  ['weve', 'drunk', 'enough', 'said', 'armen'],
#  ['morn',
#   'will',
#   'be',
#   'upon',
#   'us',
#   'sooner',
#   'than',
#   'wed',
#   'like',
#   'and',
#   'archmaester',
#   'ebrose',
#   'will',
#   'be',
#   'speaking',
#   'on',
#   'the',
#   'properties',
#   'of',
#   'urine'],
#  ['those',
#   'who',
#   'mean',
#   'to',
#   'forge',
#   'silver',
#   'link',
#   'would',
#   'do',
#   'well',
#   'not',
#   'to',
#   'miss',
#   'his',
#   'talk'],
#  ['far',
#   'be',
#   'it',
#   'from',
#   'me',
#   'to',
#   'keep',
#   'you',
#   'from',
#   'the',
#   'piss',
#   'tasting',
#   'said',
#   'leo'],
#  ['myself', 'prefer', 'the', 'taste', 'of', 'arbor', 'gold'],
#  ['if', 'the', 'choice', 'is', 'piss', 'or', 'you', 'ill', 'drink', 'piss'],
#  ['mollander', 'pushed', 'back', 'from', 'the', 'table'],
#  ['come', 'roone'],
#  ['the', 'sphinx', 'reached', 'for', 'his', 'bowcase'],
#  ['its', 'bed', 'for', 'me', 'as', 'well'],
#  ['expect', 'ill', 'dream', 'of', 'dragons', 'and', 'glass', 'candles'],
#  ['all', 'of', 'you'],
#  ['leo', 'shrugged'],
#  ['well', 'rosey', 'will', 'remain'],
#  ['perhaps',
#   'ill',
#   'wake',
#   'our',
#   'little',
#   'sweetmeat',
#   'and',
#   'make',
#   'woman',
#   'of',
#   'her'],
#  ['alleras', 'saw', 'the', 'look', 'on', 'pates', 'face'],
#  ['if',
#   'he',
#   'does',
#   'not',
#   'have',
#   'copper',
#   'for',
#   'cup',
#   'of',
#   'wine',
#   'he',
#   'cannot',
#   'have',
#   'dragon',
#   'for',
#   'the',
#   'girl'],
#  ['aye', 'said', 'mollander'],
#  ['besides', 'it', 'takes', 'man', 'to', 'make', 'woman'],
#  ['come', 'with', 'us', 'pate'],
#  ['old', 'walgrave', 'will', 'wake', 'when', 'the', 'sun', 'comes', 'up'],
#  ['hell', 'be', 'needing', 'you', 'to', 'help', 'him', 'to', 'the', 'privy'],
#  ['if', 'he', 'remembers', 'who', 'am', 'today'],
#  ['archmaester',
#   'walgrave',
#   'had',
#   'no',
#   'trouble',
#   'telling',
#   'one',
#   'raven',
#   'from',
#   'another',
#   'but',
#   'he',
#   'was',
#   'not',
#   'so',
#   'good',
#   'with',
#   'people'],
#  ['some',
#   'days',
#   'he',
#   'seemed',
#   'to',
#   'think',
#   'pate',
#   'was',
#   'someone',
#   'named',
#   'cressen'],
#  ['not', 'just', 'yet', 'he', 'told', 'his', 'friends'],
#  ['im', 'going', 'to', 'stay', 'awhile'],
#  ['dawn', 'had', 'not', 'broken', 'not', 'quite'],
#  ['the',
#   'alchemist',
#   'might',
#   'still',
#   'be',
#   'coming',
#   'and',
#   'pate',
#   'meant',
#   'to',
#   'be',
#   'here',
#   'if',
#   'he',
#   'did'],
#  ['as', 'you', 'wish', 'said', 'armen'],
#  ['alleras',
#   'gave',
#   'pate',
#   'lingering',
#   'look',
#   'then',
#   'slung',
#   'his',
#   'bow',
#   'over',
#   'one',
#   'slim',
#   'shoulder',
#   'and',
#   'followed',
#   'the',
#   'others',
#   'toward',
#   'the',
#   'bridge'],
#  ['mollander',
#   'was',
#   'so',
#   'drunk',
#   'he',
#   'had',
#   'to',
#   'walk',
#   'with',
#   'hand',
#   'on',
#   'roones',
#   'shoulder',
#   'to',
#   'keep',
#   'from',
#   'falling'],
#  ['the',
#   'citadel',
#   'was',
#   'no',
#   'great',
#   'distance',
#   'as',
#   'the',
#   'raven',
#   'flies',
#   'but',
#   'none',
#   'of',
#   'them',
#   'were',
#   'ravens',
#   'and',
#   'oldtown',
#   'was',
#   'veritable',
#   'labyrinth',
#   'of',
#   'city',
#   'all',
#   'wynds',
#   'and',
#   'crisscrossing',
#   'alleys',
#   'and',
#   'narrow',
#   'crookback',
#   'streets'],
#  ['careful',
#   'pate',
#   'heard',
#   'armen',
#   'say',
#   'as',
#   'the',
#   'river',
#   'mists',
#   'swallowed',
#   'up',
#   'the',
#   'four',
#   'of',
#   'them',
#   'the',
#   'night',
#   'is',
#   'damp',
#   'and',
#   'the',
#   'cobbles',
#   'will',
#   'be',
#   'slippery'],
#  ['when',
#   'they',
#   'were',
#   'gone',
#   'lazy',
#   'leo',
#   'considered',
#   'pate',
#   'sourly',
#   'across',
#   'the',
#   'table'],
#  ['how', 'sad'],
#  ['the',
#   'sphinx',
#   'has',
#   'stolen',
#   'off',
#   'with',
#   'all',
#   'his',
#   'silver',
#   'abandoning',
#   'me',
#   'to',
#   'spotted',
#   'pate',
#   'the',
#   'pig',
#   'boy'],
#  ['he', 'stretched', 'yawning'],
#  ['how', 'is', 'our', 'lovely', 'little', 'rosey', 'pray'],
#  ['shes', 'sleeping', 'pate', 'said', 'curtly'],
#  ['naked', 'dont', 'doubt'],
#  ['leo', 'grinned'],
#  ['do', 'you', 'think', 'shes', 'truly', 'worth', 'dragon'],
#  ['one', 'day', 'suppose', 'must', 'find', 'out'],
#  ['pate', 'knew', 'better', 'than', 'to', 'reply', 'to', 'that'],
#  ['leo', 'needed', 'no', 'reply'],
#  ['expect',
#   'that',
#   'once',
#   'ive',
#   'broken',
#   'in',
#   'the',
#   'wench',
#   'her',
#   'price',
#   'will',
#   'fall',
#   'to',
#   'where',
#   'even',
#   'pig',
#   'boys',
#   'will',
#   'be',
#   'able',
#   'to',
#   'afford',
#   'her'],
#  ['you', 'ought', 'to', 'thank', 'me'],
#  ['ought',
#   'to',
#   'kill',
#   'you',
#   'pate',
#   'thought',
#   'but',
#   'he',
#   'was',
#   'not',
#   'near',
#   'drunk',
#   'enough',
#   'to',
#   'throw',
#   'away',
#   'his',
#   'life'],
#  ['leo',
#   'had',
#   'been',
#   'trained',
#   'to',
#   'arms',
#   'and',
#   'was',
#   'known',
#   'to',
#   'be',
#   'deadly',
#   'with',
#   'bravos',
#   'blade',
#   'and',
#   'dagger'],
#  ['and',
#   'if',
#   'pate',
#   'should',
#   'somehow',
#   'kill',
#   'him',
#   'it',
#   'would',
#   'mean',
#   'his',
#   'own',
#   'head',
#   'too'],
#  ['leo',
#   'had',
#   'two',
#   'names',
#   'where',
#   'pate',
#   'had',
#   'only',
#   'one',
#   'and',
#   'his',
#   'second',
#   'was',
#   'tyrell'],
#  ['ser',
#   'moryn',
#   'tyrell',
#   'commander',
#   'of',
#   'the',
#   'city',
#   'watch',
#   'of',
#   'oldtown',
#   'was',
#   'leos',
#   'father'],
#  ['mace',
#   'tyrell',
#   'lord',
#   'of',
#   'highgarden',
#   'and',
#   'warden',
#   'of',
#   'the',
#   'south',
#   'was',
#   'leos',
#   'cousin'],
#  ['and',
#   'oldtowns',
#   'old',
#   'man',
#   'lord',
#   'leyton',
#   'of',
#   'the',
#   'hightower',
#   'who',
#   'numbered',
#   'protector',
#   'of',
#   'the',
#   'citadel',
#   'amongst',
#   'his',
#   'many',
#   'titles',
#   'was',
#   'sworn',
#   'bannerman',
#   'of',
#   'house',
#   'tyrell'],
#  ['let', 'it', 'go', 'pate', 'told', 'himself'],
#  ['he', 'says', 'these', 'things', 'just', 'to', 'wound', 'me'],
#  ['the', 'mists', 'were', 'lightening', 'to', 'the', 'east'],
#  ['dawn', 'pate', 'realized'],
#  ['dawn', 'has', 'come', 'and', 'the', 'alchemist', 'has', 'not'],
#  ['he', 'did', 'not', 'know', 'whether', 'he', 'should', 'laugh', 'or', 'cry'],
#  ['am',
#   'still',
#   'thief',
#   'if',
#   'put',
#   'it',
#   'all',
#   'back',
#   'and',
#   'no',
#   'one',
#   'ever',
#   'knows'],
#  ['it',
#   'was',
#   'another',
#   'question',
#   'that',
#   'he',
#   'had',
#   'no',
#   'answer',
#   'for',
#   'like',
#   'those',
#   'that',
#   'ebrose',
#   'and',
#   'vaellyn',
#   'had',
#   'once',
#   'asked',
#   'him'],
#  ['when',
#   'he',
#   'pushed',
#   'back',
#   'from',
#   'the',
#   'bench',
#   'and',
#   'got',
#   'to',
#   'his',
#   'feet',
#   'the',
#   'fearsomely',
#   'strong',
#   'cider',
#   'all',
#   'went',
#   'to',
#   'his',
#   'head',
#   'at',
#   'once'],
#  ['he',
#   'had',
#   'to',
#   'put',
#   'hand',
#   'on',
#   'the',
#   'table',
#   'to',
#   'steady',
#   'himself'],
#  ['leave', 'rosey', 'be', 'he', 'said', 'by', 'way', 'of', 'parting'],
#  ['just', 'leave', 'her', 'be', 'or', 'may', 'kill', 'you'],
#  ['leo', 'tyrell', 'flicked', 'the', 'hair', 'back', 'from', 'his', 'eye'],
#  ['do', 'not', 'fight', 'duels', 'with', 'pig', 'boys'],
#  ['go', 'away'],
#  ['pate', 'turned', 'and', 'crossed', 'the', 'terrace'],
#  ['his',
#   'heels',
#   'rang',
#   'against',
#   'the',
#   'weathered',
#   'planks',
#   'of',
#   'the',
#   'old',
#   'bridge'],
#  ['by',
#   'the',
#   'time',
#   'he',
#   'reached',
#   'the',
#   'other',
#   'side',
#   'the',
#   'eastern',
#   'sky',
#   'was',
#   'turning',
#   'pink'],
#  ['the', 'world', 'is', 'wide', 'he', 'told', 'himself'],
#  ['if',
#   'bought',
#   'that',
#   'donkey',
#   'could',
#   'still',
#   'wander',
#   'the',
#   'roads',
#   'and',
#   'byways',
#   'of',
#   'the',
#   'seven',
#   'kingdoms',
#   'leeching',
#   'the',
#   'smallfolk',
#   'and',
#   'picking',
#   'nits',
#   'out',
#   'of',
#   'their',
#   'hair'],
#  ['could',
#   'sign',
#   'on',
#   'to',
#   'some',
#   'ship',
#   'pull',
#   'an',
#   'oar',
#   'and',
#   'sail',
#   'to',
#   'qarth',
#   'by',
#   'the',
#   'jade',
#   'gates',
#   'to',
#   'see',
#   'these',
#   'bloody',
#   'dragons',
#   'for',
#   'myself'],
#  ['do',
#   'not',
#   'need',
#   'to',
#   'go',
#   'back',
#   'to',
#   'old',
#   'walgrave',
#   'and',
#   'the',
#   'ravens'],
#  ['yet',
#   'somehow',
#   'his',
#   'feet',
#   'turned',
#   'back',
#   'toward',
#   'the',
#   'citadel'],
#  ['when',
#   'the',
#   'first',
#   'shaft',
#   'of',
#   'sunlight',
#   'broke',
#   'through',
#   'the',
#   'clouds',
#   'to',
#   'the',
#   'east',
#   'morning',
#   'bells',
#   'began',
#   'to',
#   'peal',
#   'from',
#   'the',
#   'sailors',
#   'sept',
#   'down',
#   'by',
#   'the',
#   'harbor'],
#  ['the',
#   'lords',
#   'sept',
#   'joined',
#   'in',
#   'moment',
#   'later',
#   'then',
#   'the',
#   'seven',
#   'shrines',
#   'from',
#   'their',
#   'gardens',
#   'across',
#   'the',
#   'honeywine',
#   'and',
#   'finally',
#   'the',
#   'starry',
#   'sept',
#   'that',
#   'had',
#   'been',
#   'the',
#   'seat',
#   'of',
#   'the',
#   'high',
#   'septon',
#   'for',
#   'thousand',
#   'years',
#   'before',
#   'aegon',
#   'landed',
#   'at',
#   'kings',
# ...
#   'to',
#   'preach',
#   'and',
#   'in',
#   'the',
#   'yards',
#   'of',
#   'petty',
#   'lords',
#   'as',
#   'well'],
#  ['we',
#   'were',
#   'born',
#   'from',
#   'the',
#   'sea',
#   'and',
#   'to',
#   'the',
#   'sea',
#   'we',
#   'all',
#   'return',
#   'he',
#   'told',
#   'them'],
#  ['his',
#   'voice',
#   'was',
#   'as',
#   'deep',
#   'as',
#   'the',
#   'ocean',
#   'and',
#   'thundered',
#   'like',
#   'the',
#   'waves'],
#  ['the',
#   'storm',
#   'god',
#   'in',
#   'his',
#   'wrath',
#   'plucked',
#   'balon',
#   'from',
#   'his',
#   'castle',
#   'and',
#   'cast',
#   'him',
#   'down',
#   'and',
#   'now',
#   'he',
#   'feasts',
#   'beneath',
#   'the',
#   'waves',
#   'in',
#   'the',
#   'drowned',
#   'gods',
#   'watery',
#   'halls'],
#  ['he', 'raised', 'his', 'hands'],
#  ['balon', 'is', 'dead'],
#  ['the', 'king', 'is', 'dead'],
#  ['yet', 'king', 'will', 'come', 'again'],
#  ['for',
#   'what',
#   'is',
#   'dead',
#   'may',
#   'never',
#   'die',
#   'but',
#   'rises',
#   'again',
#   'harder',
#   'and',
#   'stronger'],
#  ['king', 'will', 'rise'],
#  ['some',
#   'of',
#   'those',
#   'who',
#   'heard',
#   'him',
#   'threw',
#   'down',
#   'their',
#   'hoes',
#   'and',
#   'picks',
#   'to',
#   'follow',
#   'so',
#   'by',
#   'the',
#   'time',
#   'he',
#   'heard',
#   'the',
#   'crash',
#   'of',
#   'waves',
#   'dozen',
#   'men',
#   'walked',
#   'behind',
#   'his',
#   'horse',
#   'touched',
#   'by',
#   'god',
#   'and',
#   'desirous',
#   'of',
#   'drowning'],
#  ['pebbleton',
#   'was',
#   'home',
#   'to',
#   'several',
#   'thousand',
#   'fisherfolk',
#   'whose',
#   'hovels',
#   'huddled',
#   'round',
#   'the',
#   'base',
#   'of',
#   'square',
#   'towerhouse',
#   'with',
#   'turret',
#   'at',
#   'each',
#   'corner'],
#  ['twoscore',
#   'of',
#   'aerons',
#   'drowned',
#   'men',
#   'there',
#   'awaited',
#   'him',
#   'camped',
#   'along',
#   'grey',
#   'sand',
#   'beach',
#   'in',
#   'sealskin',
#   'tents',
#   'and',
#   'shelters',
#   'built',
#   'of',
#   'driftwood'],
#  ['their',
#   'hands',
#   'were',
#   'roughened',
#   'by',
#   'brine',
#   'scarred',
#   'by',
#   'nets',
#   'and',
#   'lines',
#   'callused',
#   'from',
#   'oars',
#   'and',
#   'picks',
#   'and',
#   'axes',
#   'but',
#   'now',
#   'those',
#   'hands',
#   'gripped',
#   'driftwood',
#   'cudgels',
#   'hard',
#   'as',
#   'iron',
#   'for',
#   'the',
#   'god',
#   'had',
#   'armed',
#   'them',
#   'from',
#   'his',
#   'arsenal',
#   'beneath',
#   'the',
#   'sea'],
#  ['they',
#   'had',
#   'built',
#   'shelter',
#   'for',
#   'the',
#   'priest',
#   'just',
#   'above',
#   'the',
#   'tideline'],
#  ['gladly',
#   'he',
#   'crawled',
#   'into',
#   'it',
#   'after',
#   'he',
#   'had',
#   'drowned',
#   'his',
#   'newest',
#   'followers'],
#  ['my',
#   'god',
#   'he',
#   'prayed',
#   'speak',
#   'to',
#   'me',
#   'in',
#   'the',
#   'rumble',
#   'of',
#   'the',
#   'waves',
#   'and',
#   'tell',
#   'me',
#   'what',
#   'to',
#   'do'],
#  ['the', 'captains', 'and', 'the', 'kings', 'await', 'your', 'word'],
#  ['who', 'shall', 'be', 'our', 'king', 'in', 'balons', 'place'],
#  ['sing',
#   'to',
#   'me',
#   'in',
#   'the',
#   'language',
#   'of',
#   'leviathan',
#   'that',
#   'may',
#   'know',
#   'his',
#   'name'],
#  ['tell',
#   'me',
#   'lord',
#   'beneath',
#   'the',
#   'waves',
#   'who',
#   'has',
#   'the',
#   'strength',
#   'to',
#   'fight',
#   'the',
#   'storm',
#   'on',
#   'pyke'],
#  ['though',
#   'his',
#   'ride',
#   'to',
#   'hammerhorn',
#   'had',
#   'left',
#   'him',
#   'weary',
#   'aeron',
#   'damphair',
#   'was',
#   'restless',
#   'in',
#   'his',
#   'driftwood',
#   'shelter',
#   'roofed',
#   'over',
#   'with',
#   'black',
#   'weeds',
#   'from',
#   'the',
#   'sea'],
#  ['the',
#   'clouds',
#   'rolled',
#   'in',
#   'to',
#   'cloak',
#   'the',
#   'moon',
#   'and',
#   'stars',
#   'and',
#   'the',
#   'darkness',
#   'lay',
#   'as',
#   'thick',
#   'upon',
#   'the',
#   'sea',
#   'as',
#   'it',
#   'did',
#   'upon',
#   'his',
#   'soul'],
#  ['balon',
#   'favored',
#   'asha',
#   'the',
#   'child',
#   'of',
#   'his',
#   'body',
#   'but',
#   'woman',
#   'cannot',
#   'rule',
#   'the',
#   'ironborn'],
#  ['it', 'must', 'be', 'victarion'],
#  ['nine',
#   'sons',
#   'had',
#   'been',
#   'born',
#   'from',
#   'the',
#   'loins',
#   'of',
#   'quellon',
#   'greyjoy',
#   'and',
#   'victarion',
#   'was',
#   'the',
#   'strongest',
#   'of',
#   'them',
#   'bull',
#   'of',
#   'man',
#   'fearless',
#   'and',
#   'dutiful'],
#  ['and', 'therein', 'lies', 'our', 'danger'],
#  ['younger',
#   'brother',
#   'owes',
#   'obedience',
#   'to',
#   'an',
#   'elder',
#   'and',
#   'victarion',
#   'was',
#   'not',
#   'man',
#   'to',
#   'sail',
#   'against',
#   'tradition'],
#  ['he', 'has', 'no', 'love', 'for', 'euron', 'though'],
#  ['not', 'since', 'the', 'woman', 'died'],
#  ['outside',
#   'beneath',
#   'the',
#   'snoring',
#   'of',
#   'his',
#   'drowned',
#   'men',
#   'and',
#   'the',
#   'keening',
#   'of',
#   'the',
#   'wind',
#   'he',
#   'could',
#   'hear',
#   'the',
#   'pounding',
#   'of',
#   'the',
#   'waves',
#   'the',
#   'hammer',
#   'of',
#   'his',
#   'god',
#   'calling',
#   'him',
#   'to',
#   'battle'],
#  ['aeron',
#   'crept',
#   'from',
#   'his',
#   'little',
#   'shelter',
#   'into',
#   'the',
#   'chill',
#   'of',
#   'the',
#   'night'],
#  ['naked',
#   'he',
#   'stood',
#   'pale',
#   'and',
#   'gaunt',
#   'and',
#   'tall',
#   'and',
#   'naked',
#   'he',
#   'walked',
#   'into',
#   'the',
#   'black',
#   'salt',
#   'sea'],
#  ['the',
#   'water',
#   'was',
#   'icy',
#   'cold',
#   'yet',
#   'he',
#   'did',
#   'not',
#   'flinch',
#   'from',
#   'his',
#   'gods',
#   'caress'],
#  ['wave', 'smashed', 'against', 'his', 'chest', 'staggering', 'him'],
#  ['the', 'next', 'broke', 'over', 'his', 'head'],
#  ['he',
#   'could',
#   'taste',
#   'the',
#   'salt',
#   'on',
#   'his',
#   'lips',
#   'and',
#   'feel',
#   'the',
#   'god',
#   'around',
#   'him',
#   'and',
#   'his',
#   'ears',
#   'rang',
#   'with',
#   'the',
#   'glory',
#   'of',
#   'his',
#   'song'],
#  ['nine',
#   'sons',
#   'were',
#   'born',
#   'from',
#   'the',
#   'loins',
#   'of',
#   'quellon',
#   'greyjoy',
#   'and',
#   'was',
#   'the',
#   'least',
#   'of',
#   'them',
#   'as',
#   'weak',
#   'and',
#   'frightened',
#   'as',
#   'girl'],
#  ['but', 'no', 'longer'],
#  ['that',
#   'man',
#   'is',
#   'drowned',
#   'and',
#   'the',
#   'god',
#   'has',
#   'made',
#   'me',
#   'strong'],
#  ['the',
#   'cold',
#   'salt',
#   'sea',
#   'surrounded',
#   'him',
#   'embraced',
#   'him',
#   'reached',
#   'down',
#   'through',
#   'his',
#   'weak',
#   'mans',
#   'flesh',
#   'and',
#   'touched',
#   'his',
#   'bones'],
#  ['bones', 'he', 'thought'],
#  ['the', 'bones', 'of', 'the', 'soul'],
#  ['balons', 'bones', 'and', 'urris'],
#  ['the',
#   'truth',
#   'is',
#   'in',
#   'our',
#   'bones',
#   'for',
#   'flesh',
#   'decays',
#   'and',
#   'bone',
#   'endures'],
#  ['and',
#   'on',
#   'the',
#   'hill',
#   'of',
#   'nagga',
#   'the',
#   'bones',
#   'of',
#   'the',
#   'grey',
#   'kings',
#   'hall',
#   'and',
#   'gaunt',
#   'and',
#   'pale',
#   'and',
#   'shivering',
#   'aeron',
#   'damphair',
#   'struggled',
#   'back',
#   'to',
#   'the',
#   'shore',
#   'wiser',
#   'man',
#   'than',
#   'he',
#   'had',
#   'been',
#   'when',
#   'he',
#   'stepped',
#   'into',
#   'the',
#   'sea'],
#  ['for',
#   'he',
#   'had',
#   'found',
#   'the',
#   'answer',
#   'in',
#   'his',
#   'bones',
#   'and',
#   'the',
#   'way',
#   'was',
#   'plain',
#   'before',
#   'him'],
#  ['the',
#   'night',
#   'was',
#   'so',
#   'cold',
#   'that',
#   'his',
#   'body',
#   'seemed',
#   'to',
#   'steam',
#   'as',
#   'he',
#   'stalked',
#   'back',
#   'toward',
#   'his',
#   'shelter',
#   'but',
#   'there',
#   'was',
#   'fire',
#   'burning',
#   'in',
#   'his',
#   'heart',
#   'and',
#   'sleep',
#   'came',
#   'easily',
#   'for',
#   'once',
#   'unbroken',
#   'by',
#   'the',
#   'scream',
#   'of',
#   'iron',
#   'hinges'],
#  ['when', 'he', 'woke', 'the', 'day', 'was', 'bright', 'and', 'windy'],
#  ['aeron',
#   'broke',
#   'his',
#   'fast',
#   'on',
#   'broth',
#   'of',
#   'clams',
#   'and',
#   'seaweed',
#   'cooked',
#   'above',
#   'driftwood',
#   'fire'],
#  ['no',
#   'sooner',
#   'had',
#   'he',
#   'finished',
#   'than',
#   'the',
#   'merlyn',
#   'descended',
#   'from',
#   'his',
#   'towerhouse',
#   'with',
#   'half',
#   'dozen',
#   'guards',
#   'to',
#   'seek',
#   'him',
#   'out'],
#  ['the', 'king', 'is', 'dead', 'the', 'damphair', 'told', 'him'],
#  ['aye'],
#  ['had', 'bird'],
#  ['and', 'now', 'another'],
#  ['the',
#   'merlyn',
#   'was',
#   'bald',
#   'round',
#   'fleshy',
#   'man',
#   'who',
#   'styled',
#   'himself',
#   'lord',
#   'in',
#   'the',
#   'manner',
#   'of',
#   'the',
#   'green',
#   'lands',
#   'and',
#   'dressed',
#   'in',
#   'furs',
#   'and',
#   'velvets'],
#  ['one',
#   'raven',
#   'summons',
#   'me',
#   'to',
#   'pyke',
#   'another',
#   'to',
#   'ten',
#   'towers'],
#  ['you',
#   'krakens',
#   'have',
#   'too',
#   'many',
#   'arms',
#   'you',
#   'pull',
#   'man',
#   'to',
#   'pieces'],
#  ['what', 'say', 'you', 'priest'],
#  ['where', 'should', 'send', 'my', 'longships'],
#  ['aeron', 'scowled'],
#  ['ten', 'towers', 'do', 'you', 'say'],
#  ['what', 'kraken', 'calls', 'you', 'there'],
#  ['ten', 'towers', 'was', 'the', 'seat', 'of', 'the', 'lord', 'of', 'harlaw'],
#  ['the', 'princess', 'asha'],
#  ['she', 'has', 'set', 'her', 'sails', 'for', 'home'],
#  ['the',
#   'reader',
#   'sends',
#   'out',
#   'ravens',
#   'summoning',
#   'all',
#   'her',
#   'friends',
#   'to',
#   'harlaw'],
#  ['he',
#   'says',
#   'that',
#   'balon',
#   'meant',
#   'for',
#   'her',
#   'to',
#   'sit',
#   'the',
#   'seastone',
#   'chair'],
#  ['the',
#   'drowned',
#   'god',
#   'shall',
#   'decide',
#   'who',
#   'sits',
#   'the',
#   'seastone',
#   'chair',
#   'the',
#   'priest',
#   'said'],
#  ['kneel', 'that', 'might', 'bless', 'you'],
#  ['lord',
#   'merlyn',
#   'sank',
#   'to',
#   'his',
#   'knees',
#   'and',
#   'aeron',
#   'uncorked',
#   'his',
#   'skin',
#   'and',
#   'poured',
#   'stream',
#   'of',
#   'seawater',
#   'on',
#   'his',
#   'bald',
#   'pate'],
#  ['lord',
#   'god',
#   'who',
#   'drowned',
#   'for',
#   'us',
#   'let',
#   'meldred',
#   'your',
#   'servant',
#   'be',
#   'born',
#   'again',
#   'from',
#   'the',
#   'sea'],
#  ['bless',
#   'him',
#   'with',
#   'salt',
#   'bless',
#   'him',
#   'with',
#   'stone',
#   'bless',
#   'him',
#   'with',
#   'steel'],
#  ['water',
#   'ran',
#   'down',
#   'merlyns',
#   'fat',
#   'cheeks',
#   'to',
#   'soak',
#   'his',
#   'beard',
#   'and',
#   'fox',
#   'fur',
#   'mantle'],
#  ['what',
#   'is',
#   'dead',
#   'may',
#   'never',
#   'die',
#   'aeron',
#   'finished',
#   'but',
#   'rises',
#   'again',
#   'harder',
#   'and',
#   'stronger'],
#  ['but',
#   'when',
#   'merlyn',
#   'rose',
#   'he',
#   'told',
#   'him',
#   'stay',
#   'and',
#   'listen',
#   'that',
#   'you',
#   'may',
#   'spread',
#   'gods',
#   'word'],
#  ['three',
#   'feet',
#   'from',
#   'the',
#   'waters',
#   'edge',
#   'the',
#   'waves',
#   'broke',
#   'around',
#   'rounded',
#   'granite',
#   'boulder'],
#  ['it',
#   'was',
#   'there',
#   'that',
#   'aeron',
#   'damphair',
#   'stood',
#   'so',
#   'all',
#   'his',
#   'school',
#   'might',
#   'see',
#   'him',
#   'and',
#   'hear',
#   'the',
#   'words',
#   'he',
#   'had',
#   'to',
#   'say'],
#  ['we',
#   'were',
#   'born',
#   'from',
#   'the',
#   'sea',
#   'and',
#   'to',
#   'the',
#   'sea',
#   'we',
#   'all',
#   'return',
#   'he',
#   'began',
#   'as',
#   'he',
#   'had',
#   'hundred',
#   'times',
#   'before'],
#  ['the',
#   'storm',
#   'god',
#   'in',
#   'his',
#   'wrath',
#   'plucked',
#   'balon',
#   'from',
#   'his',
#   'castle',
#   'and',
#   'cast',
#   'him',
#   'down',
#   'and',
#   'now',
#   'he',
#   'feasts',
#   'beneath',
#   'the',
#   'waves'],
#  ['he', 'raised', 'his', 'hands'],
#  ['the', 'iron', 'king', 'is', 'dead'],
#  ['yet', 'king', 'will', 'come', 'again'],
#  ['for',
#   'what',
#   'is',
#   'dead',
#   'may',
#   'never',
#   'die',
#   'but',
#   'rises',
#   'again',
#   'harder',
#   'and',
#   'stronger'],
#  ['king', 'shall', 'rise'],
#  ['the', 'drowned', 'men', 'cried'],
#  ['he', 'shall'],
#  ['he', 'must'],
#  ['but', 'who'],
#  ['the',
#   'damphair',
#   'listened',
#   'moment',
#   'but',
#   'only',
#   'the',
#   'waves',
#   'gave',
#   'answer'],
#  ['who', 'shall', 'be', 'our', 'king'],
#  ['the',
#   'drowned',
#   'men',
#   'began',
#   'to',
#   'slam',
#   'their',
#   'driftwood',
#   'cudgels',
#   'one',
#   'against',
#   'the',
#   'other'],
#  ['damphair'],
#  ['they', 'cried'],
#  ['damphair', 'king'],
#  ['aeron', 'king'],
#  ['give', 'us', 'damphair'],
#  ['aeron', 'shook', 'his', 'head'],
#  ['if',
#   'father',
#   'has',
#   'two',
#   'sons',
#   'and',
#   'gives',
#   'to',
#   'one',
#   'an',
#   'axe',
#   'and',
#   'to',
#   'the',
#   'other',
#   'net',
#   'which',
#   'does',
#   'he',
#   'intend',
#   'should',
#   'be',
#   'the',
#   'warrior'],
#  ['the',
#   'axe',
#   'is',
#   'for',
#   'the',
#   'warrior',
#   'rus',
#   'shouted',
#   'back',
#   'the',
#   'net',
#   'for',
#   'fisher',
#   'of',
#   'the',
#   'seas'],
#  ['aye', 'said', 'aeron'],
#  ['the',
#   'god',
#   'took',
#   'me',
#   'deep',
#   'beneath',
#   'the',
#   'waves',
#   'and',
#   'drowned',
#   'the',
#   'worthless',
#   'thing',
#   'was'],
#  ['when',
#   'he',
#   'cast',
#   'me',
#   'forth',
#   'again',
#   'he',
#   'gave',
#   'me',
#   'eyes',
#   'to',
#   'see',
#   'ears',
#   'to',
#   'hear',
#   'and',
#   'voice',
#   'to',
#   'spread',
#   'his',
#   'word',
#   'that',
#   'might',
#   'be',
#   'his',
#   'prophet',
#   'and',
#   'teach',
#   'his',
#   'truth',
#   'to',
#   'those',
#   'who',
#   'have',
#   'forgotten'],
#  ['was',
#   'not',
#   'made',
#   'to',
#   'sit',
#   'upon',
#   'the',
#   'seastone',
#   'chair',
#   'no',
#   'more',
#   'than',
#   'euron',
#   'crows',
#   'eye'],
#  ['for',
#   'have',
#   'heard',
#   'the',
#   'god',
#   'who',
#   'says',
#   'no',
#   'godless',
#   'man',
#   'may',
#   'sit',
#   'my',
#   'seastone',
#   'chair'],
#  ['the', 'merlyn', 'crossed', 'his', 'arms', 'against', 'his', 'chest'],
#  ['is', 'it', 'asha', 'then'],
#  ['or', 'victarion'],
#  ['tell', 'us', 'priest'],
#  ['the', 'drowned', 'god', 'will', 'tell', 'you', 'but', 'not', 'here'],
#  ['aeron', 'pointed', 'at', 'the', 'merlyns', 'fat', 'white', 'face'],
#  ['look',
#   'not',
#   'to',
#   'me',
#   'nor',
#   'to',
#   'the',
#   'laws',
#   'of',
#   'men',
#   'but',
#   'to',
#   'the',
#   'sea'],
#  ['raise',
#   'your',
#   'sails',
#   'and',
#   'unship',
#   'your',
#   'oars',
#   'my',
#   'lord',
#   'and',
#   'take',
#   'yourself',
#   'to',
#   'old',
#   'wyk'],
#  ['you', 'and', 'all', 'the', 'captains', 'and', 'the', 'kings'],
#  ['go',
#   'not',
#   'to',
#   'pyke',
#   'to',
#   'bow',
#   'before',
#   'the',
#   'godless',
#   'nor',
#   'to',
#   'harlaw',
#   'to',
#   'consort',
#   'with',
#   'scheming',
#   'women'],
#  ['point',
#   'your',
#   'prow',
#   'toward',
#   'old',
#   'wyk',
#   'where',
#   'stood',
#   'the',
#   'grey',
#   'kings',
#   'hall'],
#  ['in', 'the', 'name', 'of', 'the', 'drowned', 'god', 'summon', 'you'],
#  ['summon', 'all', 'of', 'you'],
#  ['leave',
#   'your',
#   'halls',
#   'and',
#   'hovels',
#   'your',
#   'castles',
#   'and',
#   'your',
#   'keeps',
#   'and',
#   'return',
#   'to',
#   'naggas',
#   'hill',
#   'to',
#   'make',
#   'kingsmoot'],
#  ['the', 'merlyn', 'gaped', 'at', 'him'],
#  ['kingsmoot'],
#  ['there',
#   'has',
#   'not',
#   'been',
#   'true',
#   'kingsmoot',
#   'in',
#   'too',
#   'long',
#   'time'],
#  ['aeron', 'cried', 'in', 'anguish'],
#  ['yet',
#   'in',
#   'the',
#   'dawn',
#   'of',
#   'days',
#   'the',
#   'ironborn',
#   'chose',
#   'their',
#   'own',
#   'kings',
#   'raising',
#   'up',
#   'the',
#   'worthiest',
#   'amongst',
#   'them'],
#  ['it',
#   'is',
#   'time',
#   'we',
#   'returned',
#   'to',
#   'the',
#   'old',
#   'way',
#   'for',
#   'only',
#   'that',
#   'shall',
#   'make',
#   'us',
#   'great',
#   'again'],
#  ['it',
#   'was',
#   'kingsmoot',
#   'that',
#   'chose',
#   'urras',
#   'ironfoot',
#   'for',
#   'high',
#   'king',
#   'and',
#   'placed',
#   'driftwood',
#   'crown',
#   'upon',
#   'his',
#   'brows'],
#  ['sylas',
#   'flatnose',
#   'harrag',
#   'hoare',
#   'the',
#   'old',
#   'kraken',
#   'the',
#   'kingsmoot',
#   'raised',
#   'them',
#   'all'],
#  ['and',
#   'from',
#   'this',
#   'kingsmoot',
#   'shall',
#   'emerge',
#   'man',
#   'to',
#   'finish',
#   'the',
#   'work',
#   'king',
#   'balon',
#   'has',
#   'begun',
#   'and',
#   'win',
#   'us',
#   'back',
#   'our',
#   'freedoms'],
#  ['go',
#   'not',
#   'to',
#   'pyke',
#   'nor',
#   'to',
#   'the',
#   'ten',
#   'towers',
#   'of',
#   'harlaw',
#   'but',
#   'to',
#   'old',
#   'wyk',
#   'say',
#   'again'],
#  ['seek',
#   'the',
#   'hill',
#   'of',
#   'nagga',
#   'and',
#   'the',
#   'bones',
#   'of',
#   'the',
#   'grey',
#   'kings',
#   'hall',
#   'for',
#   'in',
#   'that',
#   'holy',
#   'place',
#   'when',
#   'the',
#   'moon',
#   'has',
#   'drowned',
#   'and',
#   'come',
#   'again',
#   'we',
#   'shall',
#   'make',
#   'ourselves',
#   'worthy',
#   'king',
#   'godly',
#   'king'],
#  ['he', 'raised', 'his', 'bony', 'hands', 'on', 'high', 'again'],
#  ['listen'],
#  ['listen', 'to', 'the', 'waves'],
#  ['listen', 'to', 'the', 'god'],
#  ['he',
#   'is',
#   'speaking',
#   'to',
#   'us',
#   'and',
#   'he',
#   'says',
#   'we',
#   'shall',
#   'have',
#   'no',
#   'king',
#   'but',
#   'from',
#   'the',
#   'kingsmoot'],
#  ['roar',
#   'went',
#   'up',
#   'at',
#   'that',
#   'and',
#   'the',
#   'drowned',
#   'men',
#   'beat',
#   'their',
#   'cudgels',
#   'one',
#   'against',
#   'the',
#   'other'],
#  ['kingsmoot'],
#  ...]

# %%
model = gensim.models.Word2Vec(
    window = 10,
    min_count = 2
)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count,epochs=model.epochs)
# Out:
# (6575433, 8625265)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('targaryen', 0.809368908405304),
#  ('stormborn', 0.800145149230957),
#  ('queen', 0.7465435266494751),
#  ('martell', 0.7385020852088928),
#  ('princess', 0.7347253561019897),
#  ('myrcella', 0.7263883948326111),
#  ('rhaegar', 0.7212420105934143),
#  ('elia', 0.6993552446365356),
#  ('aegon', 0.6985810399055481),
#  ('unburnt', 0.6985244154930115)]

# %%
model.wv.doesnt_match(['jon','robb', 'arya','sansa','bran'])
# Out:
# 'jon'

# %%
model.wv.doesnt_match(['cersei','jaime','bronn','tyrion'])
# Out:
# 'bronn'

# %%
model.wv['king']
# Out:
# array([ 3.0248656 , -0.10798474, -0.07704743, -3.490832  , -2.1234899 ,
#         3.0474818 ,  1.722814  , -1.2260878 ,  0.5492021 ,  1.9066156 ,
#         1.050795  ,  0.16541624, -1.2615935 ,  1.2127389 ,  0.03496513,
#        -1.597619  ,  1.5951482 , -1.9002732 , -3.678     , -1.6898291 ,
#         4.4363685 ,  1.4365383 , -0.592061  , -1.5618182 ,  0.8675324 ,
#         0.6657709 , -2.6393282 ,  1.0906824 , -0.05745761,  0.26558504,
#        -0.9079156 ,  2.4006455 , -3.9284985 , -0.7404829 ,  2.073936  ,
#         0.1617974 , -0.33074045, -1.5318899 , -0.23878588, -1.2105038 ,
#        -0.94203913,  0.21739408,  1.8215415 ,  1.0546753 ,  2.3832898 ,
#        -1.0530419 , -0.82439435,  1.6540912 ,  1.8225033 , -0.1776267 ,
#         0.58182144, -0.8183112 ,  1.3249258 , -1.2773132 , -1.659293  ,
#        -0.86368656,  1.0189884 ,  1.2256433 , -0.10903779, -1.3178306 ,
#         1.0680189 , -0.81028086,  1.2182631 ,  2.3213494 , -0.09898835,
#         0.97658855, -0.8568673 ,  0.65569484,  0.41939187, -1.6397043 ,
#         0.14694999,  1.9061561 , -1.5963525 , -3.6377704 ,  0.2284677 ,
#         1.3219482 ,  0.13544928, -2.6672192 ,  0.96146727,  1.6214825 ,
#        -0.32789418, -0.06988515, -1.7009766 , -1.4326367 ,  2.117254  ,
#        -1.0427066 ,  0.3634365 ,  1.5887307 , -2.549634  ,  0.70205665,
#         2.699336  ,  0.19403757,  2.607699  , -0.8240218 , -0.95097303,
#        -0.37426388,  0.18810509,  0.42806613, -0.5412436 ,  1.3465651 ],
#       dtype=float32)

# %%
model.wv.similarity('arya','sansa')
# Out:
# 0.85654175

# %%
model.wv.similarity('cersei','sansa')
# Out:
# 0.755524

# %%
model.wv.similarity('arya','cersei')
# Out:
# 0.5101964

# %%
model.wv.similarity('tywin','sansa')
# Out:
# 0.18772982

# %%
model.wv.get_normed_vectors()
# Out:
# array([[ 0.05211553, -0.06923325,  0.05902821, ..., -0.20221302,
#          0.06327977,  0.13361698],
#        [ 0.02359874, -0.01843069,  0.15612225, ..., -0.10755911,
#         -0.11599757,  0.10523463],
#        [ 0.07730222, -0.12775525, -0.0157951 , ..., -0.06818893,
#          0.22304535, -0.0535293 ],
#        ...,
#        [-0.19543415, -0.00410976, -0.05690809, ...,  0.02395168,
#         -0.2001587 ,  0.00918635],
#        [ 0.20272434,  0.01450271,  0.1029831 , ..., -0.04564957,
#          0.0314519 , -0.01383458],
#        [ 0.02399164, -0.02833077,  0.16228737, ..., -0.05637568,
#         -0.16907166,  0.03223312]], dtype=float32)

# %%
model.wv.get_normed_vectors().shape
# Out:
# (17869, 100)

# %%
y = model.wv.index_to_key

# %%
y
# Out:
# ['the',
#  'and',
#  'to',
#  'of',
#  'he',
#  'his',
#  'was',
#  'you',
#  'her',
#  'in',
#  'it',
#  'had',
#  'that',
#  'she',
#  'as',
#  'with',
#  'him',
#  'not',
#  'but',
#  'for',
#  'they',
#  'is',
#  'at',
#  'on',
#  'said',
#  'my',
#  'have',
#  'be',
#  'them',
#  'lord',
#  'no',
#  'from',
#  'were',
#  'would',
#  'me',
#  'your',
#  'one',
#  'all',
#  'when',
#  'will',
#  'ser',
#  'if',
#  'so',
#  'their',
#  'could',
#  'are',
#  'we',
#  'man',
#  'there',
#  'this',
#  'up',
#  'been',
#  'what',
#  'did',
#  'by',
#  'do',
#  'men',
#  'back',
#  'out',
#  'more',
#  'or',
#  'king',
#  'who',
#  'well',
#  'down',
#  'than',
#  'only',
#  'like',
#  'jon',
#  'some',
#  'old',
#  'hand',
#  'even',
#  'too',
#  'before',
#  'never',
#  'tyrion',
#  'an',
#  'off',
#  'know',
#  'see',
#  'into',
#  'made',
#  'father',
#  'now',
#  'eyes',
#  'black',
#  'told',
#  'thought',
#  'lady',
#  'time',
#  'then',
#  'how',
#  'long',
#  'has',
#  'might',
#  'us',
#  'come',
#  'where',
#  'here',
#  'can',
#  'through',
#  'still',
#  'face',
#  'head',
#  'red',
#  'way',
#  'page',
#  'boy',
#  'must',
#  'once',
#  'good',
#  'two',
#  'over',
#  'little',
#  'about',
#  'brother',
#  'took',
#  'came',
#  'other',
#  'though',
#  'again',
#  'say',
#  'night',
#  'three',
#  'should',
#  'away',
#  'queen',
#  'dead',
#  'own',
#  'its',
#  'am',
#  'son',
#  'blood',
#  'take',
#  'go',
#  'half',
#  'make',
#  'arya',
#  'saw',
#  'white',
#  'day',
#  'first',
#  'himself',
#  'jaime',
#  'our',
#  'look',
#  'want',
#  'after',
#  'much',
#  'enough',
#  'tell',
#  'sword',
#  'great',
#  'looked',
#  'bran',
#  'll',
#  'girl',
#  'left',
#  'knew',
#  'asked',
#  'gave',
#  'called',
#  'wall',
#  'every',
#  'heard',
#  'maester',
#  'yet',
#  'went',
#  'let',
#  'sansa',
#  'turned',
#  'why',
#  'need',
#  'behind',
#  'dany',
#  'around',
#  'just',
#  'another',
#  'beneath',
#  'across',
#  'snow',
#  'keep',
#  'gods',
#  'found',
#  'knight',
#  'woman',
#  'gold',
#  'any',
#  'last',
#  'grace',
#  'those',
#  'castle',
#  'think',
#  'many',
#  'hair',
#  'feet',
#  'against',
#  'cersei',
#  'hands',
#  'stark',
#  'stannis',
#  'seemed',
#  'catelyn',
#  'may',
#  'ever',
#  'done',
#  'robb',
#  'find',
#  'mother',
#  'prince',
#  'lannister',
#  'hear',
#  'grey',
#  'name',
#  'high',
#  'robert',
#  'put',
#  'stone',
#  'wine',
#  'horse',
#  'hard',
#  'upon',
#  'iron',
#  'fire',
#  'water',
#  'until',
#  'these',
#  'voice',
#  'gone',
#  'give',
#  'seen',
#  'shall',
#  'better',
#  'always',
#  'years',
#  'ned',
#  'between',
#  'dark',
#  'sam',
#  'place',
#  'cold',
#  'small',
#  'most',
#  'hundred',
#  'winterfell',
#  'stood',
#  'end',
#  'words',
#  'right',
#  'sea',
#  'nothing',
#  'sister',
#  'walls',
#  'fingers',
#  'same',
#  'cloak',
#  'house',
#  'young',
#  'does',
#  'beside',
#  'get',
#  'mouth',
#  'seven',
#  'watch',
#  'door',
#  'green',
#  'big',
#  'under',
#  'few',
#  'sent',
#  'joffrey',
#  'brothers',
#  'perhaps',
#  'almost',
#  'such',
#  'wanted',
#  'true',
#  'while',
#  'leave',
#  'don',
#  'kings',
#  'arms',
#  'light',
#  'wind',
#  'daughter',
#  'herself',
#  'sweet',
#  'others',
#  'lost',
#  'children',
#  'city',
#  'each',
#  'felt',
#  're',
#  'theon',
#  'side',
#  'yes',
#  'best',
#  'very',
#  'die',
#  'brought',
#  'soon',
#  'far',
#  'died',
#  'north',
#  'fear',
#  'lords',
#  'along',
#  'word',
#  'both',
#  'child',
#  'taken',
#  'help',
#  'battle',
#  'new',
#  'brienne',
#  'davos',
#  'something',
#  'mean',
#  'rest',
#  'hall',
#  'wife',
#  'kill',
#  'sons',
#  'steel',
#  'strong',
#  'days',
#  'began',
#  'sound',
#  'past',
#  'tywin',
#  'dragons',
#  'tower',
#  'killed',
#  'life',
#  'arm',
#  'tried',
#  'knights',
#  'free',
#  'thing',
#  'bloody',
#  'bear',
#  'pale',
#  'love',
#  'sat',
#  'bring',
#  'bed',
#  'heart',
#  'horses',
#  'moment',
#  'close',
#  'cut',
#  'smile',
#  'inside',
#  'dragon',
#  'brown',
#  'hot',
#  'four',
#  'death',
#  'silver',
#  'open',
#  'part',
#  'thousand',
#  'nor',
#  'landing',
#  'above',
#  'going',
#  'blue',
#  'air',
#  'please',
#  'bastard',
#  'laughed',
#  'uncle',
#  'rose',
#  'river',
#  'war',
#  'fell',
#  'sun',
#  'wolf',
#  'swords',
#  'golden',
#  'sleep',
#  'without',
#  'speak',
#  'full',
#  'certain',
#  'beyond',
#  'feel',
#  'send',
#  'got',
#  'fight',
#  'set',
#  'tongue',
#  'rode',
#  'thick',
#  'captain',
#  'fool',
#  'throat',
#  'renly',
#  'legs',
#  'deep',
#  'call',
#  'world',
#  'trees',
#  'won',
#  'rock',
#  'honor',
#  'tall',
#  'pulled',
#  'table',
#  'broken',
#  'steps',
#  'things',
#  'women',
#  'next',
#  'heavy',
#  'burned',
#  'oh',
#  'toward',
#  'together',
#  'given',
#  'skin',
#  'mormont',
#  'hodor',
#  'since',
#  'smiled',
#  'moved',
#  'alone',
#  'raised',
#  'ride',
#  'ask',
#  'hope',
#  'eye',
#  'soft',
#  'reached',
#  'second',
#  'remember',
#  've',
#  'remembered',
#  'coming',
#  'dwarf',
#  'meant',
#  'hold',
#  'cannot',
#  'ten',
#  'morning',
#  'frey',
#  'teeth',
#  'else',
#  'throne',
#  'someone',
#  'command',
#  'fat',
#  'which',
#  'truth',
#  'doubt',
#  'ground',
#  'cup',
#  'outside',
#  'known',
#  'wore',
#  'ran',
#  'gate',
#  'held',
#  'room',
#  'jorah',
#  'wed',
#  'ships',
#  'closed',
#  'commander',
#  'home',
#  'matter',
#  'south',
#  'sky',
#  'wood',
#  'storm',
#  'people',
#  'dozen',
#  'ill',
#  'neck',
#  'near',
#  'food',
#  'instead',
#  'turn',
#  'talk',
#  'riverrun',
#  'none',
#  'walder',
#  'below',
#  'shadow',
#  'lips',
#  'watched',
#  'leather',
#  'times',
#  'summer',
#  'varys',
#  'moon',
#  'shoulder',
#  'warm',
#  'tyrell',
#  'caught',
#  'believe',
#  'least',
#  'guards',
#  'boys',
#  'septon',
#  'answer',
#  'blade',
#  'ice',
#  'wondered',
#  'mine',
#  'shield',
#  'opened',
#  'armor',
#  'safe',
#  'six',
#  'bolton',
#  'kept',
#  'wish',
#  'return',
#  'barristan',
#  'used',
#  'smell',
#  'less',
#  'foot',
#  'being',
#  'floor',
#  'squire',
#  'friends',
#  'empty',
#  'run',
#  'followed',
#  'serve',
#  'beard',
#  'cloaks',
#  'wedding',
#  'wrong',
#  'eat',
#  'daenerys',
#  'flesh',
#  'sight',
#  'five',
#  'strength',
#  'ghost',
#  'baratheon',
#  'nose',
#  'returned',
#  'bones',
#  'yellow',
#  'girls',
#  'chest',
#  'god',
#  'covered',
#  'hound',
#  'says',
#  'commanded',
#  'eddard',
#  'crown',
#  'sometimes',
#  'filled',
#  'led',
#  'aye',
#  'yours',
#  'common',
#  'show',
#  'flames',
#  'spoke',
#  'aside',
#  'huge',
#  'fighting',
#  'friend',
#  'crows',
#  'belly',
#  'seem',
#  'ship',
#  'breath',
#  'yard',
#  'gates',
#  'waiting',
#  'within',
#  'looking',
#  'wooden',
#  'wet',
#  'lysa',
#  'realm',
#  'petyr',
#  'asha',
#  'work',
#  'thin',
#  'promised',
#  'use',
#  'bad',
#  'wildlings',
#  'grew',
#  'later',
#  'onto',
#  'tree',
#  'loved',
#  'afraid',
#  'shoulders',
#  'master',
#  'rain',
#  'shouted',
#  'walked',
#  'late',
#  'fall',
#  'aemon',
#  'liked',
#  'guard',
#  'remained',
#  'tommen',
#  'passed',
#  'mance',
#  'hurt',
#  'year',
#  'maid',
#  'taste',
#  'littlefinger',
#  'dothraki',
#  'drew',
#  'lay',
#  'greyjoy',
#  'husband',
#  'pushed',
#  'realized',
#  'spear',
#  'song',
#  'sure',
#  'named',
#  'different',
#  'finally',
#  'stand',
#  'whispered',
#  'brave',
#  'reach',
#  'suddenly',
#  'wolves',
#  'poor',
#  'dog',
#  'kingsguard',
#  'stay',
#  'lannisters',
#  'stop',
#  'kingdoms',
#  'broke',
#  'ears',
#  'drogo',
#  'princess',
#  'burning',
#  'faces',
#  'dream',
#  'axe',
#  'west',
#  'tears',
#  'heir',
#  'drink',
#  'meereen',
#  'darkness',
#  'either',
#  'pointed',
#  'try',
#  'direwolf',
#  'sworn',
#  'forward',
#  'pain',
#  'arryn',
#  'lie',
#  'hill',
#  'raven',
#  'truly',
#  'khal',
#  'grown',
#  'clegane',
#  'ones',
#  'nights',
#  'seat',
#  'dagger',
#  'born',
#  'edmure',
#  'care',
#  'harrenhal',
#  'road',
#  'round',
#  'helm',
#  'bronn',
#  'margaery',
#  'feast',
#  'amongst',
#  'meat',
#  'understand',
#  'quick',
#  'longer',
#  'lifted',
#  'whilst',
#  'reminded',
#  'maybe',
#  'short',
#  'step',
#  'third',
#  'dont',
#  'pycelle',
#  'worse',
#  'pretty',
#  'stopped',
#  'lands',
#  'bit',
#  'sit',
#  'sharp',
#  'save',
#  'rodrik',
#  'knows',
#  'whose',
#  'fathers',
#  'live',
#  'smoke',
#  'pray',
#  'leg',
#  'window',
#  'younger',
#  'horn',
#  'westeros',
#  'balon',
#  'heads',
#  'twenty',
#  'silk',
#  'slaves',
#  'pie',
#  'peace',
#  'ago',
#  'mountain',
#  'low',
#  'wants',
#  'laugh',
#  'towers',
#  'mind',
#  'east',
#  'blind',
#  'mad',
#  'myself',
#  'sooner',
#  'bright',
#  'bread',
#  'slain',
#  'older',
#  'making',
#  'coin',
#  'camp',
#  'narrow',
#  'salt',
#  'drowned',
#  'walk',
#  'wait',
#  'point',
#  'septa',
#  'glanced',
#  'melisandre',
#  'served',
#  'cheeks',
#  'dogs',
#  'reek',
#  'often',
#  'shook',
#  'quiet',
#  'riding',
#  'stepped',
#  'sort',
#  'touched',
#  'knife',
#  'targaryen',
#  'twisted',
#  'naked',
#  'choice',
#  'during',
#  'fish',
#  'silence',
#  'luwin',
#  'forgotten',
#  'victarion',
#  'hung',
#  'read',
#  'loras',
#  'gift',
#  'fallen',
#  'running',
#  'replied',
#  'knees',
#  'aegon',
#  'large',
#  'silent',
#  'fought',
#  'ahead',
#  'kevan',
#  'dawn',
#  'beautiful',
#  'needs',
#  'pass',
#  'knee',
#  'casterly',
#  'company',
#  'mud',
#  'themselves',
#  'cousin',
#  'stupid',
#  'body',
#  'court',
#  'trying',
#  'sept',
#  'age',
#  'top',
#  'tully',
#  'dorne',
#  'kind',
#  'sisters',
#  'swear',
#  'gendry',
#  'meera',
#  'offered',
#  'closer',
#  'clothes',
#  'leaves',
#  'whole',
#  'anything',
#  'kiss',
#  'gregor',
#  'agreed',
#  'whatever',
#  'cat',
#  'wonder',
#  'pay',
#  'lion',
#  'threw',
#  'answered',
#  'queens',
#  'climbed',
#  'saddle',
#  'wide',
#  'saying',
#  'didn',
#  'stars',
#  'comes',
#  'stones',
#  'hizdahr',
#  'chain',
#  'trust',
#  'hed',
#  'host',
#  'trident',
#  'daughters',
#  'pleased',
#  'fair',
#  'yourself',
#  'ear',
#  'spears',
#  'dry',
#  'insisted',
#  'dying',
#  'eight',
#  'fast',
#  'hes',
#  'singer',
#  'woods',
#  'carried',
#  'service',
#  'ought',
#  'doors',
#  'hour',
#  'fist',
#  'mail',
#  'council',
#  'needed',
#  'milk',
#  'crossed',
#  'join',
#  'fine',
#  'thank',
#  'tent',
#  'finger',
#  'doing',
#  'names',
#  'wildling',
#  'boots',
#  'land',
#  'shadows',
#  'helped',
#  'win',
#  'somehow',
#  'kissed',
#  'crow',
#  'banners',
#  'folk',
#  'letter',
#  'screamed',
#  'angry',
#  'pink',
#  'frightened',
#  'bird',
#  'torch',
#  'learn',
#  'alive',
#  'fires',
#  'winter',
#  'watching',
#  'im',
#  'dragonstone',
#  'harm',
#  'chair',
#  'rhaegar',
#  'easy',
#  'nine',
#  'learned',
#  'neither',
#  'serving',
#  'standing',
#  'imp',
#  'question',
#  'wings',
#  'drunk',
#  'eunuch',
#  'nodded',
#  'sail',
#  'bone',
#  'forth',
#  'warned',
#  'slow',
#  'field',
#  'slipped',
#  'slid',
#  'falling',
#  'priest',
#  'slowly',
#  'ramsay',
#  'dreams',
#  'bronze',
#  'promise',
#  'harbor',
#  'quentyn',
#  'atop',
#  'rise',
#  'move',
#  'line',
#  'flowers',
#  'slave',
#  'makes',
#  'gilly',
#  'laughter',
#  'loose',
#  'earth',
#  'bay',
#  'declared',
#  'faced',
#  'grass',
#  'viserys',
#  'power',
#  'lived',
#  'twice',
#  'front',
#  'captains',
#  'happened',
#  'because',
#  'cell',
#  'chains',
#  'dance',
#  'myrcella',
#  'break',
#  'play',
#  'surely',
#  'clean',
#  'oldtown',
#  'whore',
#  'pyke',
#  'unless',
#  'claim',
#  'cried',
#  'fresh',
#  'quite',
#  'aerys',
#  'waters',
#  'illyrio',
#  'pair',
#  'tarly',
#  'morrow',
#  'met',
#  'shouting',
#  'game',
#  'thats',
#  'sad',
#  'already',
#  'laid',
#  'rule',
#  'jeyne',
#  'softly',
#  'eyrie',
#  'ravens',
#  'touch',
#  'count',
#  'sense',
#  'woke',
#  'started',
#  'mounted',
#  ...]

# %%
len(y)
# Out:
# 17869

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
x = pca.fit_transform(model.wv.get_normed_vectors())

# %%
x[:5]
# Out:
# array([[-0.20664483,  0.5910391 ,  0.01195314],
#        [-0.20715335,  0.34773195,  0.06244829],
#        [ 0.2592371 ,  0.5541945 ,  0.26561612],
#        [-0.04136316,  0.3817622 , -0.10204093],
#        [ 0.06740718,  0.52173364,  0.3128348 ]], dtype=float32)

# %%
import plotly.express as px

# %%
import plotly.express as px
fig = px.scatter_3d(x[:100],x=0, y=1, z=2, color=y[:100])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9437ded6-c0d8-4aa2-96a5-927a6a7c7202" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9437ded6-c0d8-4aa2-96a5-927a6a7c7202")) {                    Plotly.newPlot(                        "9437ded6-c0d8-4aa2-96a5-927a6a7c7202",                        [{"hovertemplate":"color=the\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"the","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"the","scene":"scene","showlegend":true,"x":[-0.20664483308792114],"y":[0.5910391211509705],"z":[0.01195314060896635],"type":"scatter3d"},{"hovertemplate":"color=and\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"and","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"and","scene":"scene","showlegend":true,"x":[-0.2071533501148224],"y":[0.34773194789886475],"z":[0.06244829297065735],"type":"scatter3d"},{"hovertemplate":"color=to\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"to","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"to","scene":"scene","showlegend":true,"x":[0.2592371106147766],"y":[0.5541945099830627],"z":[0.26561611890792847],"type":"scatter3d"},{"hovertemplate":"color=of\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"of","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"of","scene":"scene","showlegend":true,"x":[-0.04136316105723381],"y":[0.38176220655441284],"z":[-0.10204093158245087],"type":"scatter3d"},{"hovertemplate":"color=he\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"he","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"he","scene":"scene","showlegend":true,"x":[0.06740718334913254],"y":[0.5217336416244507],"z":[0.31283479928970337],"type":"scatter3d"},{"hovertemplate":"color=his\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"his","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"his","scene":"scene","showlegend":true,"x":[-0.05465911328792572],"y":[0.2638598084449768],"z":[0.32207754254341125],"type":"scatter3d"},{"hovertemplate":"color=was\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"was","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"was","scene":"scene","showlegend":true,"x":[0.062068793922662735],"y":[0.3639799952507019],"z":[0.31422513723373413],"type":"scatter3d"},{"hovertemplate":"color=you\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"you","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"you","scene":"scene","showlegend":true,"x":[0.5213764905929565],"y":[0.6107268333435059],"z":[0.17150291800498962],"type":"scatter3d"},{"hovertemplate":"color=her\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"her","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"her","scene":"scene","showlegend":true,"x":[-0.047996461391448975],"y":[0.36369994282722473],"z":[0.36197158694267273],"type":"scatter3d"},{"hovertemplate":"color=in\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"in","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"in"," ...
